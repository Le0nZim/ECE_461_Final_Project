# %% [markdown]
# # Libraries <br>
#
# - **!pip install scikit-surprise** <br> <br>
#
# - **pip install sentence-transformers** <br> <br>
#
# - **pip install keras or pip install tensorflow depending on the tensorflow version**  <br>

# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %% [markdown]
# # Read data

# %%
movies = pd.read_csv("movies.csv")
ratings = pd.read_csv("ratings.csv")
tags = pd.read_csv("tags.csv")
links = pd.read_csv("links.csv")

# %% [markdown]
# # View data

# %%
movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
links.head()
# Out:
#    movieId  imdbId   tmdbId
# 0        1  114709    862.0
# 1        2  113497   8844.0
# 2        3  113228  15602.0
# 3        4  114885  31357.0
# 4        5  113041  11862.0

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
tags.head()
# Out:
#    userId  movieId              tag   timestamp
# 0       2    60756            funny  1445714994
# 1       2    60756  Highly quotable  1445714996
# 2       2    60756     will ferrell  1445714992
# 3       2    89774     Boxing story  1445715207
# 4       2    89774              MMA  1445715200

# %%
print(tags.shape, ratings.shape, movies.shape)
# Out:
# (3683, 4) (100836, 4) (9742, 3)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# # Profile data

# %% [markdown]
# # Pandas profiling

# %%
import ydata_profiling
from ydata_profiling import ProfileReport

movie_profile = ProfileReport(movies)
ratings_profile = ProfileReport(ratings)
tags_profile = ProfileReport(tags)
# Save the profile report to an HTML file
movie_profile.to_file("movies_profile_report.html")
ratings_profile.to_file("ratings_report.html")
tags_profile.to_file("tags_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Observations from pandas profiling

# %% [markdown]
# **Ratings Distribution** <br>
# They have a mean value around 3.5 according to pandas profiling
# ![Rating Distribution](distribution_ratings.png)

# %% [markdown]
# # Most popular genres in movie dataframe

# %%
genre_counts = movies['genres'].value_counts()

# %%
print(genre_counts)
# Out:
# Drama                                                  1053
# Comedy                                                  946
# Comedy|Drama                                            435
# Comedy|Romance                                          363
# Drama|Romance                                           349
#                                                        ...
# Action|Crime|Horror|Mystery|Thriller                      1
# Adventure|Animation|Children|Comedy|Musical|Romance       1
# Action|Adventure|Animation|Comedy|Crime|Mystery           1
# Children|Comedy|Fantasy|Sci-Fi                            1
# Action|Animation|Comedy|Fantasy                           1
# Name: genres, Length: 951, dtype: int64

# %% [markdown]
# **Word Cloud genres** <br>
# Drama comedy Romance are the most common genres
# ![Genre Counts](cloud_word_genres.png)

# %% [markdown]
# **Word Cloud tags** <br>
# Comedy netflix dark atmospheric are the common tags that users comment
# ![tags Counts](word_cloud_tags.png)

# %% [markdown]
# # High rating users and Top rated movies

# %%
# Calculate average rating for each user
average_ratings = ratings.groupby('userId')['rating'].mean()

# Identify users with high average ratings
high_rating_users = average_ratings[average_ratings >= 4.5]

# Print the user IDs of users with high average ratings
print(high_rating_users.index.tolist())
# Out:
# [25, 30, 43, 53, 122, 171, 251, 348, 371, 400, 441, 452, 515, 523]

# %%
# Calculate average rating for each movie
average_ratings = ratings.groupby('movieId')['rating'].mean()

# Sort movies by average rating in descending order
sorted_movies = average_ratings.sort_values(ascending=False)

# Select top-rated movies (top 5 here)
top_rated_movies = sorted_movies.head(5)

# %%
top_rated_movies
# Out:
# movieId
# 88448     5.0
# 100556    5.0
# 143031    5.0
# 143511    5.0
# 143559    5.0
# Name: rating, dtype: float64

# %%
movies[movies['movieId'] == 88448]
# Out:
#       movieId                                  title        genres
# 7656    88448  Paper Birds (Pájaros de papel) (2010)  Comedy|Drama

# %%
# Merge the two DataFrames based on the "movieId" column
top_rated_movies_titles = pd.merge(top_rated_movies, movies, on='movieId')

# %%
top_rated_movies_titles
# Out:
#    movieId  rating                                  title  \
# 0    88448     5.0  Paper Birds (Pájaros de papel) (2010)
# 1   100556     5.0             Act of Killing, The (2012)
# 2   143031     5.0                        Jump In! (2007)
# 3   143511     5.0                           Human (2015)
# 4   143559     5.0                    L.A. Slasher (2015)
#
#                  genres
# 0          Comedy|Drama
# 1           Documentary
# 2  Comedy|Drama|Romance
# 3           Documentary
# 4  Comedy|Crime|Fantasy

# %%
#merged_df.head()

# %% [markdown]
# # User - Movie rating dataframe

# %%
# Pivot table to create the user-movie rating matrix
rating_matrix = ratings.pivot_table(values='rating', index='userId', columns='movieId')

# %%
ratings.head()
# Out:
#    userId  movieId  rating  timestamp
# 0       1        1     4.0  964982703
# 1       1        3     4.0  964981247
# 2       1        6     4.0  964982224
# 3       1       47     5.0  964983815
# 4       1       50     5.0  964982931

# %%
rating_matrix
# Out:
# movieId  1       2       3       4       5       6       7       8       \
# userId
# 1           4.0     NaN     4.0     NaN     NaN     4.0     NaN     NaN
# 2           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 5           4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...     ...     ...     ...     ...
# 606         2.5     NaN     NaN     NaN     NaN     NaN     2.5     NaN
# 607         4.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 608         2.5     2.0     2.0     NaN     NaN     NaN     NaN     NaN
# 609         3.0     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 610         5.0     NaN     NaN     NaN     NaN     5.0     NaN     NaN
#
# movieId  9       10      ...  193565  193567  193571  193573  193579  193581  \
# userId                   ...
# 1           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 2           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 3           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 4           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 5           NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# ...         ...     ...  ...     ...     ...     ...     ...     ...     ...
# 606         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 607         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 608         NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 609         NaN     4.0  ...     NaN     NaN     NaN     NaN     NaN     NaN
# 610         NaN     NaN  ...     NaN     NaN     NaN     NaN     NaN     NaN
#
# movieId  193583  193585  193587  193609
# userId
# 1           NaN     NaN     NaN     NaN
# 2           NaN     NaN     NaN     NaN
# 3           NaN     NaN     NaN     NaN
# 4           NaN     NaN     NaN     NaN
# 5           NaN     NaN     NaN     NaN
# ...         ...     ...     ...     ...
# 606         NaN     NaN     NaN     NaN
# 607         NaN     NaN     NaN     NaN
# 608         NaN     NaN     NaN     NaN
# 609         NaN     NaN     NaN     NaN
# 610         NaN     NaN     NaN     NaN
#
# [610 rows x 9724 columns]

# %% [markdown]
# # Sparsity of the user item matrix

# %%
rating_matrix.shape
# Out:
# (610, 9724)

# %%
rating_matrix.size
# Out:
# 5931640

# %%
# Calculate the number of missing values (NaNs)
missing_values = rating_matrix.isnull().sum().sum()
print(missing_values)
# Out:
# 5830804

# %%
rated_movies = rating_matrix.size - missing_values
rated_movies
# Out:
# 100836

# %%
# Calculate the total number of possible values
total_possible_values = rating_matrix.size

# Calculate the number of missing values (NaNs)
missing_values = rating_matrix.isnull().sum().sum()

# Calculate sparsity
sparsity = missing_values / total_possible_values

# Print the sparsity
print(f"Sparsity: {sparsity:.4f}")
# Out:
# Sparsity: 0.9830

# %% [markdown]
# **User item matrix is a sparse matrix , 2% of the matrix is filled with ratings**

# %%
import os
from surprise import Dataset, SVD
from surprise import BaselineOnly, Dataset, Reader
from surprise.model_selection import cross_validate

# %% [markdown]
# # Drop timestamp

# %%
ratings = ratings.drop("timestamp",axis=1)

# %%
reader = Reader(rating_scale=(0.5, 5))


data = Dataset.load_from_df(ratings, reader)

# %%
from surprise import KNNBaseline,KNNBasic,KNNWithMeans,KNNWithZScore,NormalPredictor,BaselineOnly

# %% [markdown]
# # Baseline Model <br>
# # Normal Predictor

# %%
algo3 = NormalPredictor()
scores = cross_validate(algo3, data, measures=["RMSE", "MAE"], cv=5, verbose=True)


#RMSE MAE Evaluation
mean_rmse = np.mean(scores.get("test_rmse"))
mean_mae = np.mean(scores.get("test_mae"))
mean_fit_time = np.mean(scores.get("fit_time"))
mean_test_time = np.mean(scores.get("test_time"))
overall_time = mean_fit_time + mean_test_time
print(f"Mean RMSE is {mean_rmse:.3f}")
print(f"Mean MAE is {mean_mae:.3f}")   
print(f"Mean fit_time is {mean_fit_time:.3f}")   
print(f"Mean test_time is {mean_test_time:.3f}")   
print(f"Mean overall_time is {overall_time:.3f}")
# Out:
# Evaluating RMSE, MAE of algorithm NormalPredictor on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    1.4222  1.4202  1.4269  1.4249  1.4318  1.4252  0.0040
# MAE (testset)     1.1386  1.1351  1.1382  1.1360  1.1448  1.1385  0.0034
# Fit time          0.08    0.10    0.09    0.09    0.09    0.09    0.01
# Test time         0.23    0.06    0.06    0.06    0.19    0.12    0.07
# Mean RMSE is 1.425
# Mean MAE is 1.139
# Mean fit_time is 0.092
# Mean test_time is 0.121
# Mean overall_time is 0.212

# %% [markdown]
# # Collaborative Filtering using Matrix Factorization techniques from surprise library<br>
# - **SVD**
# - **Probabilistic Matrix Factorization**
# - **Non-Negative Matrix Factorization**
# - **BaselineOnly**

# %%
from surprise import NMF

# %%
bsl_options = {
    "method": "sgd"
}
algorithms = [SVD(), SVD(biased=False), NMF(), BaselineOnly(bsl_options=bsl_options)]

rmse_results = []
mae_results = []
fit_time = []
test_time = []
overall_times = []

for algo in algorithms:
    # Run cross-validation and get scores
    scores = cross_validate(algo, data, measures=["RMSE", "MAE"], cv=5, verbose=True)
    ####### Calculate scores  for evaluation ########
    mean_rmse = np.mean(scores.get("test_rmse"))
    mean_mae = np.mean(scores.get("test_mae"))
    
    mean_fit_time = np.mean(scores.get("fit_time"))
    mean_test_time = np.mean(scores.get("test_time"))
    overall_time = mean_fit_time + mean_test_time
    
    ####### Add elements to the lists ########
    rmse_results.append(mean_rmse)
    mae_results.append(mean_mae)
    fit_time.append(mean_fit_time)
    test_time.append(mean_test_time)
    overall_times.append(overall_time)
    
# Evaluation RMSE MAE and time 
for i, algo in enumerate(algorithms):
    curr_rmse = rmse_results[i]
    curr_mae = mae_results[i]
    curr_fit_time = fit_time[i]
    curr_test_time = test_time[i]
    curr_overall_time = overall_times[i]
    
    print("\n\n\n")
    print(f"{algo.__class__.__name__} RMSE {curr_rmse:.3f} \t MAE {curr_mae:.3f} \t Fit time {curr_fit_time:.3f} \t Test time {curr_test_time:.3f} \t Overall time {curr_overall_time:.3f}")
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8763  0.8776  0.8839  0.8692  0.8606  0.8735  0.0079
# MAE (testset)     0.6737  0.6745  0.6776  0.6706  0.6606  0.6714  0.0058
# Fit time          0.88    1.00    0.93    0.85    0.87    0.90    0.05
# Test time         0.11    0.10    0.10    0.11    0.10    0.10    0.00
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9966  0.9867  0.9833  0.9803  0.9810  0.9856  0.0060
# MAE (testset)     0.7662  0.7572  0.7567  0.7517  0.7531  0.7570  0.0051
# Fit time          0.84    0.87    0.85    0.86    0.85    0.86    0.01
# Test time         0.09    0.09    0.09    0.09    0.09    0.09    0.00
# Evaluating RMSE, MAE of algorithm NMF on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9177  0.9180  0.9133  0.9200  0.9242  0.9186  0.0035
# MAE (testset)     0.7026  0.7035  0.7005  0.7045  0.7057  0.7034  0.0018
# Fit time          1.66    1.65    1.66    1.64    1.67    1.66    0.01
# Test time         0.26    0.09    0.09    0.09    0.26    0.16    0.08
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Estimating biases using sgd...
# Evaluating RMSE, MAE of algorithm BaselineOnly on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.8793  0.8747  0.8628  0.8729  0.8584  0.8696  0.0078
# MAE (testset)     0.6739  0.6709  0.6653  0.6696  0.6630  0.6685  0.0039
# Fit time          0.34    0.38    0.34    0.36    0.36    0.36    0.01
# Test time         0.05    0.06    0.05    0.05    0.05    0.05    0.00
#
#
#
#
# SVD RMSE 0.874 	 MAE 0.671 	 Fit time 0.904 	 Test time 0.104 	 Overall time 1.008
#
#
#
#
# SVD RMSE 0.986 	 MAE 0.757 	 Fit time 0.856 	 Test time 0.091 	 Overall time 0.947
#
#
#
#
# NMF RMSE 0.919 	 MAE 0.703 	 Fit time 1.658 	 Test time 0.157 	 Overall time 1.816
#
#
#
#
# BaselineOnly RMSE 0.870 	 MAE 0.669 	 Fit time 0.357 	 Test time 0.053 	 Overall time 0.410

# %% [markdown]
# # Plot metrics for each method

# %%
import matplotlib.pyplot as plt

metrics = {
        "RMSE": rmse_results,
        "MAE": mae_results,
        "Fit_time": fit_time,
        "Test_time": test_time,
        "Overall_time": overall_times
}
    
metrics_names = list(metrics.keys())

SVD_metrics = {key: value[0] for key, value in metrics.items()}
PMF_metrics = {key: value[1] for key, value in metrics.items()}
NMF_metrics = {key: value[2] for key, value in metrics.items()}
Bsl_metrics = {key: value[3] for key, value in metrics.items()}

SVD_values = list(SVD_metrics.values())
PMF_values = list(PMF_metrics.values())
NMF_values = list(NMF_metrics.values())
Bsl_values = list(Bsl_metrics.values())

###### SVD Metrics #######

colors = ['skyblue', 'red', 'lightblue', 'magenta', 'brown']

plt.figure(figsize=(12, 6))
bars1 = plt.bar(metrics_names, SVD_values, color=colors)
plt.xlabel('Metrics')
plt.title('SVD Metrics')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(bars1, metrics_names, loc='upper center', bbox_to_anchor=(0.7, 1))

for i, value in enumerate(SVD_values):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')

plt.show()

###### PMF Metrics #######
plt.figure(figsize=(12, 6))
bars2 = plt.bar(metrics_names, PMF_values, color=colors)
plt.legend(bars2, metrics_names, loc='upper center', bbox_to_anchor=(0.7, 1))
plt.xlabel('Metrics')
plt.title('PMF Metrics')
plt.grid(axis='y', linestyle='--', alpha=0.7)

for i, value in enumerate(PMF_values):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')

plt.show()

###### NMF Metrics #######
plt.figure(figsize=(12, 6))
bars3 = plt.bar(metrics_names, NMF_values, color = colors)
plt.legend(bars3, metrics_names, loc='upper left')
plt.xlabel('Metrics')
plt.title('NMF Metrics')
plt.grid(axis='y', linestyle='--', alpha=0.7)

for i, value in enumerate(NMF_values):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')

plt.show()

###### Matrix Factorization loss function using SGD to minimize it  ######
plt.figure(figsize=(12, 6))
bars9 = plt.bar(metrics_names, Bsl_values, color=colors)
plt.xlabel('Metrics')
plt.title('BaselineOnly metrics')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.legend(bars9, metrics_names, loc='upper center', bbox_to_anchor=(0.7, 1))

for i, value in enumerate(Bsl_values):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')

plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\1848868886.py:37: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\1848868886.py:50: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\1848868886.py:63: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\1848868886.py:76: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # Compare metrics between SVD, PMF, NMF, Bsl

# %%
models = ["SVD", "PMF", "NMF", "Baseline"]

colors2 = ['blue', 'orange', 'green', "gray"]

# Plotting the bar chart
plt.figure(figsize=(12, 8))
bars = plt.bar(models, rmse_results, color=colors2)
plt.title('Comparison of RMSE Values for SVD, NMF, PMF and Baseline')
plt.xlabel('Matrix Factorization Models')
plt.ylabel('Root Mean Squared Error (RMSE)')
plt.ylim(0, max(rmse_results) + 0.1)  # Adjust the y-axis limit if needed
plt.grid(axis='y', linestyle='--', alpha=0.7)

###legend
plt.legend(bars, models, loc='upper right')

# Adding text labels with RMSE values on top of the bars
for i, value in enumerate(rmse_results):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')
    
# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\2848058949.py:22: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # MAE

# %%
plt.figure(figsize=(12, 8))
bars4 = plt.bar(models, mae_results, color=colors2)
plt.title('Comparison of MAE Values for SVD, NMF, PMF and Baseline')
plt.xlabel('Matrix Factorization Models')
plt.ylabel('Mean Squared Error (MAE)')
plt.ylim(0, max(mae_results) + 0.1)  # Adjust the y-axis limit if needed
plt.grid(axis='y', linestyle='--', alpha=0.7)

###legend
plt.legend(bars4, models, loc='upper right')

# Adding text labels with RMSE values on top of the bars
for i, value in enumerate(mae_results):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')
    
# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\960067735.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # Fit time

# %%
plt.figure(figsize=(12, 8))
bars5 = plt.bar(models, fit_time, color=colors2)
plt.title('Comparison of fit time for SVD, NMF, PMF and Baseline')
plt.xlabel('Matrix Factorization Models')
plt.ylabel('Fit time (seconds)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

###legend
plt.legend(bars5, models, loc='upper left')

# Adding text labels with RMSE values on top of the bars
for i, value in enumerate(fit_time):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')
    
# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\1074189057.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # Test time

# %%
plt.figure(figsize=(12, 8))
bars6 = plt.bar(models, test_time, color=colors2)
plt.title('Comparison of test time for SVD, NMF, PMF and Baseline')
plt.xlabel('Matrix Factorization Models')
plt.ylabel('Test time (seconds)')
plt.ylim(0, max(test_time) + 0.1)  # Adjust the y-axis limit if needed
plt.grid(axis='y', linestyle='--', alpha=0.7)

###legend
plt.legend(bars6, models, loc='upper right')

# Adding text labels with RMSE values on top of the bars
for i, value in enumerate(test_time):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')
    
# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\2060454624.py:17: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# # Overall time

# %%
plt.figure(figsize=(12, 8))
bars7 = plt.bar(models, overall_times, color=colors2)
plt.title('Comparison of overall time for SVD, NMF, PMF and Baseline')
plt.xlabel('Matrix Factorization Models')
plt.ylabel('Overall time (seconds)')
plt.grid(axis='y', linestyle='--', alpha=0.7)

###legend
plt.legend(bars7, models, loc='upper left')

# Adding text labels with RMSE values on top of the bars
for i, value in enumerate(overall_times):
    plt.text(i, value + 0.005, f'{value:.3f}', ha='center', va='bottom')
    
# Show the plot
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\3828844364.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %%
from surprise.model_selection import train_test_split

# %%
movies_and_ratings = pd.merge(movies, ratings, on='movieId')
#final_df = pd.merge(movies_and_ratings, tags, on=['movieId', 'userId'], how='left')
#final_df = final_df.drop("timestamp", axis=1)

# %% [markdown]
# # Get top 10 rated movies from a user

# %%
while True:
    user_id = input("Enter a user id (1-610): ")
    
    if not user_id.isdigit() or int(user_id) not in range(1, 611):
        print("Invalid user id. Please enter a valid id\n")
    else:
        user_id = int(user_id)
        break
    
    
    
print(f"Top 10 rated movies from user {user_id}")
# Sort the ratings in descending order for the specific user
user_sorted_ratings = movies_and_ratings[movies_and_ratings['userId'] == user_id].sort_values(by='rating', ascending = False)

# Specify the top N movies you want to retrieve
top_n = 10  

# Get the top N movies based on sorted ratings
top_movies_for_user = user_sorted_ratings.head(top_n)
top_movies_for_user
# Out:
# Enter a user id (1-610): 10
# Top 10 rated movies from user 10
#        movieId                          title  \
# 99259   140110              The Intern (2015)
# 77147     8869          First Daughter (2004)
# 94672    96079                 Skyfall (2012)
# 93816    91529  Dark Knight Rises, The (2012)
# 75192     7458                    Troy (2004)
# 92100    81845      King's Speech, The (2010)
# 76341     8533           Notebook, The (2004)
# 91318    79091           Despicable Me (2010)
# 90172    71579           Education, An (2009)
# 80014    33794           Batman Begins (2005)
#
#                                 genres  userId  rating
# 99259                           Comedy      10     5.0
# 77147                   Comedy|Romance      10     5.0
# 94672   Action|Adventure|Thriller|IMAX      10     5.0
# 93816      Action|Adventure|Crime|IMAX      10     5.0
# 75192       Action|Adventure|Drama|War      10     5.0
# 92100                            Drama      10     5.0
# 76341                    Drama|Romance      10     5.0
# 91318  Animation|Children|Comedy|Crime      10     5.0
# 90172                    Drama|Romance      10     5.0
# 80014                Action|Crime|IMAX      10     5.0

# %% [markdown]
# # Top 10 predicted ratings for a specific user

# %% [markdown]
# ## Fit an algorithm from algorithms in dataset

# %%
#####  algorithms = [SVD(), SVD(biased=False), NMF(), BaselineOnly(bsl_options=bsl_options)] ####

bsl_options = {
    "method": "sgd"
}
algorithms = [SVD(), SVD(biased=False), NMF(), BaselineOnly(bsl_options=bsl_options)]

while True:
    print("Algorithms to fit:")
    print("1.  SVD")
    print("2.  PMF")
    print("3.  NMF")
    print("4.  BaselineOnly")
    
    print("\n")
    algo = input("Enter a number (1-4): ")
    
    if not algo.isdigit() or int(algo) not in range(1, len(algorithms) + 1):
        print("Invalid choice. Please enter a valid number\n")
    else:
        algo = int(algo)
        break

trainset, testset = train_test_split(data, test_size=0.25)

algorithms[algo-1].fit(trainset)
predictions = algorithms[algo-1].test(testset)
# Out:
# Algorithms to fit:
# 1.  SVD
# 2.  PMF
# 3.  NMF
# 4.  BaselineOnly
#
#
# Enter a number (1-4): 4
# Estimating biases using sgd...

# %% [markdown]
# ## Create testset with the ratings user didnt rate

# %%
####### Get unique ids #########
unique_ids = movies["movieId"].unique()
####### Get the movies that a user rated #########
ids_rated = ratings.loc[ratings["userId"] == user_id, "movieId"]
###### Movies to predict #######
movies_to_pred = np.setdiff1d(unique_ids,ids_rated)
###### Rated movies #######
rated_movies = unique_ids.shape[0] - movies_to_pred.shape[0]


testset_user = [[user_id, mv_id, None] for mv_id in movies_to_pred]
predictions_user = algorithms[algo-1].test(testset_user)
predictions_user
# Out:
# [Prediction(uid=10, iid=1, r_ui=None, est=3.484547181119235, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2, r_ui=None, est=3.0323104084418433, details={'was_impossible': False}),
#  Prediction(uid=10, iid=3, r_ui=None, est=2.9641347183066697, details={'was_impossible': False}),
#  Prediction(uid=10, iid=4, r_ui=None, est=2.5514081797044588, details={'was_impossible': False}),
#  Prediction(uid=10, iid=5, r_ui=None, est=2.627816060792158, details={'was_impossible': False}),
#  Prediction(uid=10, iid=6, r_ui=None, est=3.5866652121000255, details={'was_impossible': False}),
#  Prediction(uid=10, iid=7, r_ui=None, est=2.81145371167914, details={'was_impossible': False}),
#  Prediction(uid=10, iid=8, r_ui=None, est=2.762310783893719, details={'was_impossible': False}),
#  Prediction(uid=10, iid=9, r_ui=None, est=2.963379754651043, details={'was_impossible': False}),
#  Prediction(uid=10, iid=10, r_ui=None, est=3.1825308973390327, details={'was_impossible': False}),
#  Prediction(uid=10, iid=11, r_ui=None, est=3.159275614398176, details={'was_impossible': False}),
#  Prediction(uid=10, iid=12, r_ui=None, est=2.281852358147076, details={'was_impossible': False}),
#  Prediction(uid=10, iid=13, r_ui=None, est=2.9399673963447728, details={'was_impossible': False}),
#  Prediction(uid=10, iid=14, r_ui=None, est=3.2521565668328014, details={'was_impossible': False}),
#  Prediction(uid=10, iid=15, r_ui=None, est=2.8715982045917974, details={'was_impossible': False}),
#  Prediction(uid=10, iid=16, r_ui=None, est=3.547301801298665, details={'was_impossible': False}),
#  Prediction(uid=10, iid=17, r_ui=None, est=3.35134120366111, details={'was_impossible': False}),
#  Prediction(uid=10, iid=18, r_ui=None, est=3.309275590393077, details={'was_impossible': False}),
#  Prediction(uid=10, iid=19, r_ui=None, est=2.4464959062507328, details={'was_impossible': False}),
#  Prediction(uid=10, iid=20, r_ui=None, est=2.5015447683954912, details={'was_impossible': False}),
#  Prediction(uid=10, iid=21, r_ui=None, est=3.163892240137025, details={'was_impossible': False}),
#  Prediction(uid=10, iid=22, r_ui=None, est=2.952740092373264, details={'was_impossible': False}),
#  Prediction(uid=10, iid=23, r_ui=None, est=2.816605171679275, details={'was_impossible': False}),
#  Prediction(uid=10, iid=24, r_ui=None, est=2.9040423223328466, details={'was_impossible': False}),
#  Prediction(uid=10, iid=25, r_ui=None, est=3.191225049768479, details={'was_impossible': False}),
#  Prediction(uid=10, iid=26, r_ui=None, est=3.1000177797460657, details={'was_impossible': False}),
#  Prediction(uid=10, iid=27, r_ui=None, est=2.980331435552353, details={'was_impossible': False}),
#  Prediction(uid=10, iid=28, r_ui=None, est=3.532332432669569, details={'was_impossible': False}),
#  Prediction(uid=10, iid=29, r_ui=None, est=3.6946302871242875, details={'was_impossible': False}),
#  Prediction(uid=10, iid=30, r_ui=None, est=2.9077217112434273, details={'was_impossible': False}),
#  Prediction(uid=10, iid=31, r_ui=None, est=2.8659855569604247, details={'was_impossible': False}),
#  Prediction(uid=10, iid=32, r_ui=None, est=3.5727478328581292, details={'was_impossible': False}),
#  Prediction(uid=10, iid=34, r_ui=None, est=3.249548738529742, details={'was_impossible': False}),
#  Prediction(uid=10, iid=36, r_ui=None, est=3.3869775926094685, details={'was_impossible': False}),
#  Prediction(uid=10, iid=38, r_ui=None, est=2.808950698287389, details={'was_impossible': False}),
#  Prediction(uid=10, iid=39, r_ui=None, est=2.8042745434007395, details={'was_impossible': False}),
#  Prediction(uid=10, iid=40, r_ui=None, est=3.224119941597233, details={'was_impossible': False}),
#  Prediction(uid=10, iid=41, r_ui=None, est=3.2493135544792007, details={'was_impossible': False}),
#  Prediction(uid=10, iid=42, r_ui=None, est=2.911128750161962, details={'was_impossible': False}),
#  Prediction(uid=10, iid=43, r_ui=None, est=2.9977123566432207, details={'was_impossible': False}),
#  Prediction(uid=10, iid=44, r_ui=None, est=2.270831856117421, details={'was_impossible': False}),
#  Prediction(uid=10, iid=45, r_ui=None, est=2.912050553866279, details={'was_impossible': False}),
#  Prediction(uid=10, iid=46, r_ui=None, est=2.616179656376464, details={'was_impossible': False}),
#  Prediction(uid=10, iid=47, r_ui=None, est=3.5494329861141547, details={'was_impossible': False}),
#  Prediction(uid=10, iid=48, r_ui=None, est=2.770976422856358, details={'was_impossible': False}),
#  Prediction(uid=10, iid=49, r_ui=None, est=3.0036154681613842, details={'was_impossible': False}),
#  Prediction(uid=10, iid=50, r_ui=None, est=3.8900893100040244, details={'was_impossible': False}),
#  Prediction(uid=10, iid=52, r_ui=None, est=3.0562974441505575, details={'was_impossible': False}),
#  Prediction(uid=10, iid=53, r_ui=None, est=3.3433072411081377, details={'was_impossible': False}),
#  Prediction(uid=10, iid=54, r_ui=None, est=2.848060313881275, details={'was_impossible': False}),
#  Prediction(uid=10, iid=55, r_ui=None, est=3.1104628808865993, details={'was_impossible': False}),
#  Prediction(uid=10, iid=57, r_ui=None, est=2.810302910710378, details={'was_impossible': False}),
#  Prediction(uid=10, iid=58, r_ui=None, est=3.620450807288024, details={'was_impossible': False}),
#  Prediction(uid=10, iid=60, r_ui=None, est=2.6868720491962303, details={'was_impossible': False}),
#  Prediction(uid=10, iid=61, r_ui=None, est=3.146869603922538, details={'was_impossible': False}),
#  Prediction(uid=10, iid=62, r_ui=None, est=3.2878120338808747, details={'was_impossible': False}),
#  Prediction(uid=10, iid=63, r_ui=None, est=2.83308901761685, details={'was_impossible': False}),
#  Prediction(uid=10, iid=64, r_ui=None, est=2.8029566295240147, details={'was_impossible': False}),
#  Prediction(uid=10, iid=65, r_ui=None, est=2.2625761116810503, details={'was_impossible': False}),
#  Prediction(uid=10, iid=66, r_ui=None, est=2.471133813558053, details={'was_impossible': False}),
#  Prediction(uid=10, iid=68, r_ui=None, est=3.0239110813275647, details={'was_impossible': False}),
#  Prediction(uid=10, iid=69, r_ui=None, est=3.3030760996375568, details={'was_impossible': False}),
#  Prediction(uid=10, iid=70, r_ui=None, est=3.330095636189327, details={'was_impossible': False}),
#  Prediction(uid=10, iid=71, r_ui=None, est=2.4316198335569648, details={'was_impossible': False}),
#  Prediction(uid=10, iid=72, r_ui=None, est=2.9864689591240197, details={'was_impossible': False}),
#  Prediction(uid=10, iid=73, r_ui=None, est=3.1122680602019055, details={'was_impossible': False}),
#  Prediction(uid=10, iid=74, r_ui=None, est=3.114632553372855, details={'was_impossible': False}),
#  Prediction(uid=10, iid=75, r_ui=None, est=2.726149285835167, details={'was_impossible': False}),
#  Prediction(uid=10, iid=76, r_ui=None, est=3.003257262788292, details={'was_impossible': False}),
#  Prediction(uid=10, iid=77, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=78, r_ui=None, est=3.0105864695959923, details={'was_impossible': False}),
#  Prediction(uid=10, iid=79, r_ui=None, est=2.5637298625105758, details={'was_impossible': False}),
#  Prediction(uid=10, iid=80, r_ui=None, est=3.1558164907122848, details={'was_impossible': False}),
#  Prediction(uid=10, iid=81, r_ui=None, est=2.731709087146779, details={'was_impossible': False}),
#  Prediction(uid=10, iid=82, r_ui=None, est=3.3549705223159023, details={'was_impossible': False}),
#  Prediction(uid=10, iid=83, r_ui=None, est=3.0536289993576187, details={'was_impossible': False}),
#  Prediction(uid=10, iid=85, r_ui=None, est=3.251799562138773, details={'was_impossible': False}),
#  Prediction(uid=10, iid=86, r_ui=None, est=3.414191888289675, details={'was_impossible': False}),
#  Prediction(uid=10, iid=87, r_ui=None, est=2.960006399213518, details={'was_impossible': False}),
#  Prediction(uid=10, iid=88, r_ui=None, est=2.86033963751687, details={'was_impossible': False}),
#  Prediction(uid=10, iid=89, r_ui=None, est=3.049052742196999, details={'was_impossible': False}),
#  Prediction(uid=10, iid=92, r_ui=None, est=2.6723068657708615, details={'was_impossible': False}),
#  Prediction(uid=10, iid=93, r_ui=None, est=2.9806280058035104, details={'was_impossible': False}),
#  Prediction(uid=10, iid=94, r_ui=None, est=3.364525313883731, details={'was_impossible': False}),
#  Prediction(uid=10, iid=95, r_ui=None, est=2.6355109386660436, details={'was_impossible': False}),
#  Prediction(uid=10, iid=96, r_ui=None, est=3.0823967338350697, details={'was_impossible': False}),
#  Prediction(uid=10, iid=97, r_ui=None, est=3.2527648590381695, details={'was_impossible': False}),
#  Prediction(uid=10, iid=99, r_ui=None, est=3.212973505593599, details={'was_impossible': False}),
#  Prediction(uid=10, iid=100, r_ui=None, est=2.64379507264813, details={'was_impossible': False}),
#  Prediction(uid=10, iid=101, r_ui=None, est=3.505495718505038, details={'was_impossible': False}),
#  Prediction(uid=10, iid=102, r_ui=None, est=2.538801400357954, details={'was_impossible': False}),
#  Prediction(uid=10, iid=103, r_ui=None, est=2.910363116757286, details={'was_impossible': False}),
#  Prediction(uid=10, iid=104, r_ui=None, est=3.117340795957642, details={'was_impossible': False}),
#  Prediction(uid=10, iid=105, r_ui=None, est=2.92954418361738, details={'was_impossible': False}),
#  Prediction(uid=10, iid=106, r_ui=None, est=3.1206626639855486, details={'was_impossible': False}),
#  Prediction(uid=10, iid=107, r_ui=None, est=3.000139514658511, details={'was_impossible': False}),
#  Prediction(uid=10, iid=108, r_ui=None, est=3.1165454393118766, details={'was_impossible': False}),
#  Prediction(uid=10, iid=110, r_ui=None, est=3.599967145030983, details={'was_impossible': False}),
#  Prediction(uid=10, iid=111, r_ui=None, est=3.665087583441652, details={'was_impossible': False}),
#  Prediction(uid=10, iid=112, r_ui=None, est=2.9603467027202752, details={'was_impossible': False}),
#  Prediction(uid=10, iid=113, r_ui=None, est=3.0015361065808364, details={'was_impossible': False}),
#  Prediction(uid=10, iid=116, r_ui=None, est=3.2148725276994297, details={'was_impossible': False}),
#  Prediction(uid=10, iid=117, r_ui=None, est=3.01599530574984, details={'was_impossible': False}),
#  Prediction(uid=10, iid=118, r_ui=None, est=2.942831152126199, details={'was_impossible': False}),
#  Prediction(uid=10, iid=119, r_ui=None, est=2.9903325592491927, details={'was_impossible': False}),
#  Prediction(uid=10, iid=121, r_ui=None, est=3.1400616877607193, details={'was_impossible': False}),
#  Prediction(uid=10, iid=122, r_ui=None, est=2.6434797683606397, details={'was_impossible': False}),
#  Prediction(uid=10, iid=123, r_ui=None, est=3.106069489560946, details={'was_impossible': False}),
#  Prediction(uid=10, iid=125, r_ui=None, est=3.2262436956162466, details={'was_impossible': False}),
#  Prediction(uid=10, iid=126, r_ui=None, est=2.518151812407725, details={'was_impossible': False}),
#  Prediction(uid=10, iid=128, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=129, r_ui=None, est=2.8898816295344574, details={'was_impossible': False}),
#  Prediction(uid=10, iid=132, r_ui=None, est=2.8552732696910246, details={'was_impossible': False}),
#  Prediction(uid=10, iid=135, r_ui=None, est=2.7222578369986374, details={'was_impossible': False}),
#  Prediction(uid=10, iid=137, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=140, r_ui=None, est=3.097702245325192, details={'was_impossible': False}),
#  Prediction(uid=10, iid=141, r_ui=None, est=3.109653816025099, details={'was_impossible': False}),
#  Prediction(uid=10, iid=144, r_ui=None, est=2.9728989279702938, details={'was_impossible': False}),
#  Prediction(uid=10, iid=145, r_ui=None, est=2.8939291894979364, details={'was_impossible': False}),
#  Prediction(uid=10, iid=146, r_ui=None, est=3.0090162548042554, details={'was_impossible': False}),
#  Prediction(uid=10, iid=147, r_ui=None, est=3.0566729613227395, details={'was_impossible': False}),
#  Prediction(uid=10, iid=148, r_ui=None, est=3.1912979150434886, details={'was_impossible': False}),
#  Prediction(uid=10, iid=149, r_ui=None, est=2.934336776008724, details={'was_impossible': False}),
#  Prediction(uid=10, iid=150, r_ui=None, est=3.43965136751079, details={'was_impossible': False}),
#  Prediction(uid=10, iid=151, r_ui=None, est=3.140455519957859, details={'was_impossible': False}),
#  Prediction(uid=10, iid=152, r_ui=None, est=2.756635845606799, details={'was_impossible': False}),
#  Prediction(uid=10, iid=153, r_ui=None, est=2.5384440258919345, details={'was_impossible': False}),
#  Prediction(uid=10, iid=154, r_ui=None, est=3.3030550817575066, details={'was_impossible': False}),
#  Prediction(uid=10, iid=155, r_ui=None, est=2.807261175163461, details={'was_impossible': False}),
#  Prediction(uid=10, iid=156, r_ui=None, est=3.000940151770295, details={'was_impossible': False}),
#  Prediction(uid=10, iid=157, r_ui=None, est=2.816828834318583, details={'was_impossible': False}),
#  Prediction(uid=10, iid=158, r_ui=None, est=2.484808120587022, details={'was_impossible': False}),
#  Prediction(uid=10, iid=159, r_ui=None, est=2.703116046323672, details={'was_impossible': False}),
#  Prediction(uid=10, iid=160, r_ui=None, est=2.5788412400522946, details={'was_impossible': False}),
#  Prediction(uid=10, iid=161, r_ui=None, est=3.227128138968984, details={'was_impossible': False}),
#  Prediction(uid=10, iid=162, r_ui=None, est=3.540073456206507, details={'was_impossible': False}),
#  Prediction(uid=10, iid=163, r_ui=None, est=3.2093930319837938, details={'was_impossible': False}),
#  Prediction(uid=10, iid=164, r_ui=None, est=2.989393790043346, details={'was_impossible': False}),
#  Prediction(uid=10, iid=165, r_ui=None, est=3.163450150725191, details={'was_impossible': False}),
#  Prediction(uid=10, iid=166, r_ui=None, est=2.9520188964390894, details={'was_impossible': False}),
#  Prediction(uid=10, iid=168, r_ui=None, est=2.686613572831782, details={'was_impossible': False}),
#  Prediction(uid=10, iid=169, r_ui=None, est=2.542634191278612, details={'was_impossible': False}),
#  Prediction(uid=10, iid=170, r_ui=None, est=3.0167231643075465, details={'was_impossible': False}),
#  Prediction(uid=10, iid=171, r_ui=None, est=3.278810353366218, details={'was_impossible': False}),
#  Prediction(uid=10, iid=172, r_ui=None, est=2.274611343786319, details={'was_impossible': False}),
#  Prediction(uid=10, iid=173, r_ui=None, est=2.3163977500911637, details={'was_impossible': False}),
#  Prediction(uid=10, iid=174, r_ui=None, est=2.6448335331298343, details={'was_impossible': False}),
#  Prediction(uid=10, iid=175, r_ui=None, est=3.569340830389432, details={'was_impossible': False}),
#  Prediction(uid=10, iid=176, r_ui=None, est=3.5017369067299216, details={'was_impossible': False}),
#  Prediction(uid=10, iid=177, r_ui=None, est=2.9140346791551712, details={'was_impossible': False}),
#  Prediction(uid=10, iid=178, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=179, r_ui=None, est=2.7127042929059564, details={'was_impossible': False}),
#  Prediction(uid=10, iid=180, r_ui=None, est=3.1964403772302785, details={'was_impossible': False}),
#  Prediction(uid=10, iid=181, r_ui=None, est=2.3448323053336244, details={'was_impossible': False}),
#  Prediction(uid=10, iid=183, r_ui=None, est=3.0209274331913587, details={'was_impossible': False}),
#  Prediction(uid=10, iid=184, r_ui=None, est=3.065650131848962, details={'was_impossible': False}),
#  Prediction(uid=10, iid=185, r_ui=None, est=2.640444720481736, details={'was_impossible': False}),
#  Prediction(uid=10, iid=186, r_ui=None, est=2.47915277056123, details={'was_impossible': False}),
#  Prediction(uid=10, iid=187, r_ui=None, est=3.417938142858759, details={'was_impossible': False}),
#  Prediction(uid=10, iid=188, r_ui=None, est=3.0623988110934226, details={'was_impossible': False}),
#  Prediction(uid=10, iid=189, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=190, r_ui=None, est=2.7773375124629354, details={'was_impossible': False}),
#  Prediction(uid=10, iid=191, r_ui=None, est=2.663815448922441, details={'was_impossible': False}),
#  Prediction(uid=10, iid=193, r_ui=None, est=1.9716693109959726, details={'was_impossible': False}),
#  Prediction(uid=10, iid=194, r_ui=None, est=3.117470956236172, details={'was_impossible': False}),
#  Prediction(uid=10, iid=195, r_ui=None, est=2.7977623760595383, details={'was_impossible': False}),
#  Prediction(uid=10, iid=196, r_ui=None, est=2.405639625453995, details={'was_impossible': False}),
#  Prediction(uid=10, iid=198, r_ui=None, est=3.0657211747038735, details={'was_impossible': False}),
#  Prediction(uid=10, iid=199, r_ui=None, est=3.2822951663414384, details={'was_impossible': False}),
#  Prediction(uid=10, iid=201, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=202, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=203, r_ui=None, est=3.040049051334061, details={'was_impossible': False}),
#  Prediction(uid=10, iid=204, r_ui=None, est=2.3650966218290437, details={'was_impossible': False}),
#  Prediction(uid=10, iid=205, r_ui=None, est=3.0633491213673256, details={'was_impossible': False}),
#  Prediction(uid=10, iid=206, r_ui=None, est=3.004428811206399, details={'was_impossible': False}),
#  Prediction(uid=10, iid=207, r_ui=None, est=3.1725507595287294, details={'was_impossible': False}),
#  Prediction(uid=10, iid=208, r_ui=None, est=2.5101640095908673, details={'was_impossible': False}),
#  Prediction(uid=10, iid=209, r_ui=None, est=3.0510548694095196, details={'was_impossible': False}),
#  Prediction(uid=10, iid=210, r_ui=None, est=3.0358089099657235, details={'was_impossible': False}),
#  Prediction(uid=10, iid=211, r_ui=None, est=3.1149456003117195, details={'was_impossible': False}),
#  Prediction(uid=10, iid=212, r_ui=None, est=3.008040004429291, details={'was_impossible': False}),
#  Prediction(uid=10, iid=213, r_ui=None, est=2.9020201922221216, details={'was_impossible': False}),
#  Prediction(uid=10, iid=214, r_ui=None, est=3.1213059391261444, details={'was_impossible': False}),
#  Prediction(uid=10, iid=215, r_ui=None, est=3.607668664656143, details={'was_impossible': False}),
#  Prediction(uid=10, iid=216, r_ui=None, est=3.0283630618117843, details={'was_impossible': False}),
#  Prediction(uid=10, iid=217, r_ui=None, est=2.6599078600757133, details={'was_impossible': False}),
#  Prediction(uid=10, iid=218, r_ui=None, est=2.9436542839705298, details={'was_impossible': False}),
#  Prediction(uid=10, iid=219, r_ui=None, est=3.0184002218797366, details={'was_impossible': False}),
#  Prediction(uid=10, iid=220, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=222, r_ui=None, est=3.1691774246692677, details={'was_impossible': False}),
#  Prediction(uid=10, iid=223, r_ui=None, est=3.640316913254825, details={'was_impossible': False}),
#  Prediction(uid=10, iid=224, r_ui=None, est=3.0870044561132164, details={'was_impossible': False}),
#  Prediction(uid=10, iid=225, r_ui=None, est=3.0508523798997293, details={'was_impossible': False}),
#  Prediction(uid=10, iid=227, r_ui=None, est=2.4911468652588624, details={'was_impossible': False}),
#  Prediction(uid=10, iid=228, r_ui=None, est=2.7257847034164007, details={'was_impossible': False}),
#  Prediction(uid=10, iid=229, r_ui=None, est=3.1423617121632774, details={'was_impossible': False}),
#  Prediction(uid=10, iid=230, r_ui=None, est=3.265353998401429, details={'was_impossible': False}),
#  Prediction(uid=10, iid=231, r_ui=None, est=2.6679013701817214, details={'was_impossible': False}),
#  Prediction(uid=10, iid=232, r_ui=None, est=3.0051434159782078, details={'was_impossible': False}),
#  Prediction(uid=10, iid=233, r_ui=None, est=3.1060523277067302, details={'was_impossible': False}),
#  Prediction(uid=10, iid=234, r_ui=None, est=2.6861070327658996, details={'was_impossible': False}),
#  Prediction(uid=10, iid=235, r_ui=None, est=3.237966152251805, details={'was_impossible': False}),
#  Prediction(uid=10, iid=236, r_ui=None, est=3.016672350384598, details={'was_impossible': False}),
#  Prediction(uid=10, iid=237, r_ui=None, est=2.913964849139457, details={'was_impossible': False}),
#  Prediction(uid=10, iid=238, r_ui=None, est=3.0219127176632132, details={'was_impossible': False}),
#  Prediction(uid=10, iid=239, r_ui=None, est=2.958508212442493, details={'was_impossible': False}),
#  Prediction(uid=10, iid=240, r_ui=None, est=2.7623793305090127, details={'was_impossible': False}),
#  Prediction(uid=10, iid=241, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=242, r_ui=None, est=3.114370573439095, details={'was_impossible': False}),
#  Prediction(uid=10, iid=243, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=246, r_ui=None, est=3.7558234420962155, details={'was_impossible': False}),
#  Prediction(uid=10, iid=247, r_ui=None, est=3.578993980581268, details={'was_impossible': False}),
#  Prediction(uid=10, iid=248, r_ui=None, est=2.915980408967228, details={'was_impossible': False}),
#  Prediction(uid=10, iid=249, r_ui=None, est=3.30571829578295, details={'was_impossible': False}),
#  Prediction(uid=10, iid=250, r_ui=None, est=2.875547970117025, details={'was_impossible': False}),
#  Prediction(uid=10, iid=251, r_ui=None, est=2.9593107181532226, details={'was_impossible': False}),
#  Prediction(uid=10, iid=252, r_ui=None, est=3.003500447919458, details={'was_impossible': False}),
#  Prediction(uid=10, iid=253, r_ui=None, est=3.1212193839297164, details={'was_impossible': False}),
#  Prediction(uid=10, iid=254, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=255, r_ui=None, est=2.3448408994640433, details={'was_impossible': False}),
#  Prediction(uid=10, iid=256, r_ui=None, est=2.60245262093456, details={'was_impossible': False}),
#  Prediction(uid=10, iid=257, r_ui=None, est=3.1031859430567788, details={'was_impossible': False}),
#  Prediction(uid=10, iid=258, r_ui=None, est=2.900536457635949, details={'was_impossible': False}),
#  Prediction(uid=10, iid=259, r_ui=None, est=2.8818267940788056, details={'was_impossible': False}),
#  Prediction(uid=10, iid=260, r_ui=None, est=3.7303526157133735, details={'was_impossible': False}),
#  Prediction(uid=10, iid=261, r_ui=None, est=3.3643955250381277, details={'was_impossible': False}),
#  Prediction(uid=10, iid=262, r_ui=None, est=3.3208633481271264, details={'was_impossible': False}),
#  Prediction(uid=10, iid=263, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=265, r_ui=None, est=3.475186284123142, details={'was_impossible': False}),
#  Prediction(uid=10, iid=266, r_ui=None, est=3.034270671420017, details={'was_impossible': False}),
#  Prediction(uid=10, iid=267, r_ui=None, est=2.8188216355837192, details={'was_impossible': False}),
#  Prediction(uid=10, iid=269, r_ui=None, est=3.027579251054163, details={'was_impossible': False}),
#  Prediction(uid=10, iid=270, r_ui=None, est=2.927451139967554, details={'was_impossible': False}),
#  Prediction(uid=10, iid=271, r_ui=None, est=2.9837254602090333, details={'was_impossible': False}),
#  Prediction(uid=10, iid=272, r_ui=None, est=3.2823640576425, details={'was_impossible': False}),
#  Prediction(uid=10, iid=273, r_ui=None, est=2.552969538049139, details={'was_impossible': False}),
#  Prediction(uid=10, iid=274, r_ui=None, est=3.07781177293416, details={'was_impossible': False}),
#  Prediction(uid=10, iid=275, r_ui=None, est=2.596456509407525, details={'was_impossible': False}),
#  Prediction(uid=10, iid=276, r_ui=None, est=2.8591583816458357, details={'was_impossible': False}),
#  Prediction(uid=10, iid=277, r_ui=None, est=2.8342402463823726, details={'was_impossible': False}),
#  Prediction(uid=10, iid=278, r_ui=None, est=2.9251287759566207, details={'was_impossible': False}),
#  Prediction(uid=10, iid=279, r_ui=None, est=3.0171982881570747, details={'was_impossible': False}),
#  Prediction(uid=10, iid=280, r_ui=None, est=3.4093720414944615, details={'was_impossible': False}),
#  Prediction(uid=10, iid=281, r_ui=None, est=3.1082868595778126, details={'was_impossible': False}),
#  Prediction(uid=10, iid=282, r_ui=None, est=2.8808181402288957, details={'was_impossible': False}),
#  Prediction(uid=10, iid=283, r_ui=None, est=3.0825993092122874, details={'was_impossible': False}),
#  Prediction(uid=10, iid=284, r_ui=None, est=3.1195771230937273, details={'was_impossible': False}),
#  Prediction(uid=10, iid=285, r_ui=None, est=3.1133972894366644, details={'was_impossible': False}),
#  Prediction(uid=10, iid=287, r_ui=None, est=3.0140678937691066, details={'was_impossible': False}),
#  Prediction(uid=10, iid=288, r_ui=None, est=2.8640623639657514, details={'was_impossible': False}),
#  Prediction(uid=10, iid=289, r_ui=None, est=3.066714189360023, details={'was_impossible': False}),
#  Prediction(uid=10, iid=290, r_ui=None, est=3.354072364266855, details={'was_impossible': False}),
#  Prediction(uid=10, iid=291, r_ui=None, est=2.959304649470623, details={'was_impossible': False}),
#  Prediction(uid=10, iid=292, r_ui=None, est=3.0791571255852266, details={'was_impossible': False}),
#  Prediction(uid=10, iid=293, r_ui=None, est=3.6228621154473077, details={'was_impossible': False}),
#  Prediction(uid=10, iid=294, r_ui=None, est=2.968148661932834, details={'was_impossible': False}),
#  Prediction(uid=10, iid=295, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=298, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=299, r_ui=None, est=3.201165237205379, details={'was_impossible': False}),
#  Prediction(uid=10, iid=300, r_ui=None, est=3.077241716191528, details={'was_impossible': False}),
#  Prediction(uid=10, iid=301, r_ui=None, est=3.1180904748220906, details={'was_impossible': False}),
#  Prediction(uid=10, iid=302, r_ui=None, est=3.0561274054679557, details={'was_impossible': False}),
#  Prediction(uid=10, iid=303, r_ui=None, est=2.7940185080213515, details={'was_impossible': False}),
#  Prediction(uid=10, iid=304, r_ui=None, est=3.1488881120721395, details={'was_impossible': False}),
#  Prediction(uid=10, iid=305, r_ui=None, est=2.8072134560545248, details={'was_impossible': False}),
#  Prediction(uid=10, iid=306, r_ui=None, est=3.5180756625278935, details={'was_impossible': False}),
#  Prediction(uid=10, iid=307, r_ui=None, est=3.416997771379426, details={'was_impossible': False}),
#  Prediction(uid=10, iid=308, r_ui=None, est=3.597800949748116, details={'was_impossible': False}),
#  Prediction(uid=10, iid=310, r_ui=None, est=3.017443942422855, details={'was_impossible': False}),
#  Prediction(uid=10, iid=311, r_ui=None, est=3.0182149279150745, details={'was_impossible': False}),
#  Prediction(uid=10, iid=312, r_ui=None, est=1.9450696440348456, details={'was_impossible': False}),
#  Prediction(uid=10, iid=313, r_ui=None, est=2.990939447930551, details={'was_impossible': False}),
#  Prediction(uid=10, iid=314, r_ui=None, est=3.3266528362216423, details={'was_impossible': False}),
#  Prediction(uid=10, iid=315, r_ui=None, est=2.6005498140768517, details={'was_impossible': False}),
#  Prediction(uid=10, iid=316, r_ui=None, est=2.9543657748862375, details={'was_impossible': False}),
#  Prediction(uid=10, iid=317, r_ui=None, est=2.775200093429716, details={'was_impossible': False}),
#  Prediction(uid=10, iid=318, r_ui=None, est=3.974798966428555, details={'was_impossible': False}),
#  Prediction(uid=10, iid=319, r_ui=None, est=3.2587147716279987, details={'was_impossible': False}),
#  Prediction(uid=10, iid=320, r_ui=None, est=3.0269195858382703, details={'was_impossible': False}),
#  Prediction(uid=10, iid=321, r_ui=None, est=3.1475660976788387, details={'was_impossible': False}),
#  Prediction(uid=10, iid=322, r_ui=None, est=3.119671786928613, details={'was_impossible': False}),
#  Prediction(uid=10, iid=324, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=325, r_ui=None, est=2.6737784250179457, details={'was_impossible': False}),
#  Prediction(uid=10, iid=326, r_ui=None, est=3.159415343231109, details={'was_impossible': False}),
#  Prediction(uid=10, iid=327, r_ui=None, est=2.532973213246693, details={'was_impossible': False}),
#  Prediction(uid=10, iid=328, r_ui=None, est=2.994111137766712, details={'was_impossible': False}),
#  Prediction(uid=10, iid=329, r_ui=None, est=3.0870671636860783, details={'was_impossible': False}),
#  Prediction(uid=10, iid=330, r_ui=None, est=3.045794229286864, details={'was_impossible': False}),
#  Prediction(uid=10, iid=331, r_ui=None, est=2.979662895685514, details={'was_impossible': False}),
#  Prediction(uid=10, iid=332, r_ui=None, est=2.7730090421638427, details={'was_impossible': False}),
#  Prediction(uid=10, iid=333, r_ui=None, est=3.3516885889786145, details={'was_impossible': False}),
#  Prediction(uid=10, iid=334, r_ui=None, est=3.382915439620938, details={'was_impossible': False}),
#  Prediction(uid=10, iid=335, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=336, r_ui=None, est=3.0179611736586063, details={'was_impossible': False}),
#  Prediction(uid=10, iid=337, r_ui=None, est=3.3745508533737025, details={'was_impossible': False}),
#  Prediction(uid=10, iid=338, r_ui=None, est=2.7839638492694876, details={'was_impossible': False}),
#  Prediction(uid=10, iid=339, r_ui=None, est=3.0086037567678745, details={'was_impossible': False}),
#  Prediction(uid=10, iid=340, r_ui=None, est=3.0542488115412714, details={'was_impossible': False}),
#  Prediction(uid=10, iid=341, r_ui=None, est=3.13454876934339, details={'was_impossible': False}),
#  Prediction(uid=10, iid=342, r_ui=None, est=2.857920106163864, details={'was_impossible': False}),
#  Prediction(uid=10, iid=343, r_ui=None, est=2.814419089612096, details={'was_impossible': False}),
#  Prediction(uid=10, iid=344, r_ui=None, est=2.5875938914444188, details={'was_impossible': False}),
#  Prediction(uid=10, iid=345, r_ui=None, est=3.2786588228399314, details={'was_impossible': False}),
#  Prediction(uid=10, iid=346, r_ui=None, est=3.1099365216695576, details={'was_impossible': False}),
#  Prediction(uid=10, iid=347, r_ui=None, est=3.1172474569568167, details={'was_impossible': False}),
#  Prediction(uid=10, iid=348, r_ui=None, est=3.241019499147554, details={'was_impossible': False}),
#  Prediction(uid=10, iid=349, r_ui=None, est=3.201365077637808, details={'was_impossible': False}),
#  Prediction(uid=10, iid=350, r_ui=None, est=3.024826611492873, details={'was_impossible': False}),
#  Prediction(uid=10, iid=351, r_ui=None, est=2.8720277509680665, details={'was_impossible': False}),
#  Prediction(uid=10, iid=352, r_ui=None, est=3.0192212918433605, details={'was_impossible': False}),
#  Prediction(uid=10, iid=353, r_ui=None, est=3.3623524718529603, details={'was_impossible': False}),
#  Prediction(uid=10, iid=354, r_ui=None, est=3.1247594007475237, details={'was_impossible': False}),
#  Prediction(uid=10, iid=355, r_ui=None, est=2.202939839659153, details={'was_impossible': False}),
#  Prediction(uid=10, iid=357, r_ui=None, est=3.1953494737592747, details={'was_impossible': False}),
#  Prediction(uid=10, iid=358, r_ui=None, est=2.602185902417122, details={'was_impossible': False}),
#  Prediction(uid=10, iid=359, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=360, r_ui=None, est=2.7776610998438374, details={'was_impossible': False}),
#  Prediction(uid=10, iid=361, r_ui=None, est=2.7611613247248172, details={'was_impossible': False}),
#  Prediction(uid=10, iid=362, r_ui=None, est=3.1169901707910883, details={'was_impossible': False}),
#  Prediction(uid=10, iid=363, r_ui=None, est=3.1477098846590263, details={'was_impossible': False}),
#  Prediction(uid=10, iid=364, r_ui=None, est=3.5209510261089387, details={'was_impossible': False}),
#  Prediction(uid=10, iid=365, r_ui=None, est=3.1425223461998693, details={'was_impossible': False}),
#  Prediction(uid=10, iid=366, r_ui=None, est=2.8864091740374307, details={'was_impossible': False}),
#  Prediction(uid=10, iid=367, r_ui=None, est=2.895392281480054, details={'was_impossible': False}),
#  Prediction(uid=10, iid=368, r_ui=None, est=3.1545864202796805, details={'was_impossible': False}),
#  Prediction(uid=10, iid=369, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=370, r_ui=None, est=2.9003737211692493, details={'was_impossible': False}),
#  Prediction(uid=10, iid=371, r_ui=None, est=3.03387069019556, details={'was_impossible': False}),
#  Prediction(uid=10, iid=372, r_ui=None, est=2.5898282548713754, details={'was_impossible': False}),
#  Prediction(uid=10, iid=373, r_ui=None, est=3.1884837860961106, details={'was_impossible': False}),
#  Prediction(uid=10, iid=374, r_ui=None, est=2.0118340813074767, details={'was_impossible': False}),
#  Prediction(uid=10, iid=376, r_ui=None, est=2.925561028226673, details={'was_impossible': False}),
#  Prediction(uid=10, iid=377, r_ui=None, est=3.1398545681564567, details={'was_impossible': False}),
#  Prediction(uid=10, iid=378, r_ui=None, est=2.959818570286263, details={'was_impossible': False}),
#  Prediction(uid=10, iid=379, r_ui=None, est=2.4096280537683126, details={'was_impossible': False}),
#  Prediction(uid=10, iid=380, r_ui=None, est=3.0534666803357484, details={'was_impossible': False}),
#  Prediction(uid=10, iid=381, r_ui=None, est=3.1854353969197473, details={'was_impossible': False}),
#  Prediction(uid=10, iid=382, r_ui=None, est=2.7697756477649813, details={'was_impossible': False}),
#  Prediction(uid=10, iid=383, r_ui=None, est=2.780325294044435, details={'was_impossible': False}),
#  Prediction(uid=10, iid=384, r_ui=None, est=3.0873433749481984, details={'was_impossible': False}),
#  Prediction(uid=10, iid=385, r_ui=None, est=3.0984026770771385, details={'was_impossible': False}),
#  Prediction(uid=10, iid=386, r_ui=None, est=3.0332559755801634, details={'was_impossible': False}),
#  Prediction(uid=10, iid=387, r_ui=None, est=2.986946732141803, details={'was_impossible': False}),
#  Prediction(uid=10, iid=388, r_ui=None, est=3.1191597915991403, details={'was_impossible': False}),
#  Prediction(uid=10, iid=389, r_ui=None, est=3.2237232369147666, details={'was_impossible': False}),
#  Prediction(uid=10, iid=390, r_ui=None, est=3.172836661605626, details={'was_impossible': False}),
#  Prediction(uid=10, iid=391, r_ui=None, est=3.2122673550997227, details={'was_impossible': False}),
#  Prediction(uid=10, iid=393, r_ui=None, est=2.727179526529444, details={'was_impossible': False}),
#  Prediction(uid=10, iid=405, r_ui=None, est=2.6085222930384537, details={'was_impossible': False}),
#  Prediction(uid=10, iid=406, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=407, r_ui=None, est=3.085107860958811, details={'was_impossible': False}),
#  Prediction(uid=10, iid=408, r_ui=None, est=2.9925920958832473, details={'was_impossible': False}),
#  Prediction(uid=10, iid=409, r_ui=None, est=2.9995155345501696, details={'was_impossible': False}),
#  Prediction(uid=10, iid=410, r_ui=None, est=2.755278606219117, details={'was_impossible': False}),
#  Prediction(uid=10, iid=412, r_ui=None, est=3.021772979133647, details={'was_impossible': False}),
#  Prediction(uid=10, iid=413, r_ui=None, est=2.60261544076037, details={'was_impossible': False}),
#  Prediction(uid=10, iid=414, r_ui=None, est=2.7630495138083075, details={'was_impossible': False}),
#  Prediction(uid=10, iid=415, r_ui=None, est=2.5992567660019112, details={'was_impossible': False}),
#  Prediction(uid=10, iid=416, r_ui=None, est=2.7641347183801495, details={'was_impossible': False}),
#  Prediction(uid=10, iid=417, r_ui=None, est=3.309933543153462, details={'was_impossible': False}),
#  Prediction(uid=10, iid=418, r_ui=None, est=3.0111932951435603, details={'was_impossible': False}),
#  Prediction(uid=10, iid=419, r_ui=None, est=2.429253947398461, details={'was_impossible': False}),
#  Prediction(uid=10, iid=420, r_ui=None, est=2.539115053993676, details={'was_impossible': False}),
#  Prediction(uid=10, iid=421, r_ui=None, est=2.9476619976895173, details={'was_impossible': False}),
#  Prediction(uid=10, iid=422, r_ui=None, est=3.02412975505795, details={'was_impossible': False}),
#  Prediction(uid=10, iid=423, r_ui=None, est=2.8128971844642763, details={'was_impossible': False}),
#  Prediction(uid=10, iid=424, r_ui=None, est=2.919750899316558, details={'was_impossible': False}),
#  Prediction(uid=10, iid=425, r_ui=None, est=3.1270179458627045, details={'was_impossible': False}),
#  Prediction(uid=10, iid=426, r_ui=None, est=3.0370534356517584, details={'was_impossible': False}),
#  Prediction(uid=10, iid=427, r_ui=None, est=2.4098441116682583, details={'was_impossible': False}),
#  Prediction(uid=10, iid=428, r_ui=None, est=3.313789851431474, details={'was_impossible': False}),
#  Prediction(uid=10, iid=429, r_ui=None, est=2.7501630116559417, details={'was_impossible': False}),
#  Prediction(uid=10, iid=430, r_ui=None, est=2.9999678095287035, details={'was_impossible': False}),
#  Prediction(uid=10, iid=431, r_ui=None, est=3.4407240672183685, details={'was_impossible': False}),
#  Prediction(uid=10, iid=432, r_ui=None, est=2.3693226133108407, details={'was_impossible': False}),
#  Prediction(uid=10, iid=433, r_ui=None, est=2.794511088341871, details={'was_impossible': False}),
#  Prediction(uid=10, iid=434, r_ui=None, est=2.6491945775537555, details={'was_impossible': False}),
#  Prediction(uid=10, iid=435, r_ui=None, est=2.201269274515237, details={'was_impossible': False}),
#  Prediction(uid=10, iid=436, r_ui=None, est=2.8390185991029595, details={'was_impossible': False}),
#  Prediction(uid=10, iid=437, r_ui=None, est=2.7394067204383425, details={'was_impossible': False}),
#  Prediction(uid=10, iid=438, r_ui=None, est=2.8383235824872055, details={'was_impossible': False}),
#  Prediction(uid=10, iid=440, r_ui=None, est=3.1814696550218082, details={'was_impossible': False}),
#  Prediction(uid=10, iid=441, r_ui=None, est=3.5986685982866247, details={'was_impossible': False}),
#  Prediction(uid=10, iid=442, r_ui=None, est=2.7712011424715843, details={'was_impossible': False}),
#  Prediction(uid=10, iid=444, r_ui=None, est=2.730361914186, details={'was_impossible': False}),
#  Prediction(uid=10, iid=445, r_ui=None, est=2.9227155641202716, details={'was_impossible': False}),
#  Prediction(uid=10, iid=446, r_ui=None, est=3.0004671137856405, details={'was_impossible': False}),
#  Prediction(uid=10, iid=448, r_ui=None, est=3.130290351025039, details={'was_impossible': False}),
#  Prediction(uid=10, iid=449, r_ui=None, est=2.8525109388288943, details={'was_impossible': False}),
#  Prediction(uid=10, iid=450, r_ui=None, est=2.8741561395078907, details={'was_impossible': False}),
#  Prediction(uid=10, iid=451, r_ui=None, est=3.1206232471284525, details={'was_impossible': False}),
#  Prediction(uid=10, iid=452, r_ui=None, est=2.9865714680853976, details={'was_impossible': False}),
#  Prediction(uid=10, iid=453, r_ui=None, est=2.8905797074181208, details={'was_impossible': False}),
#  Prediction(uid=10, iid=454, r_ui=None, est=3.123718141127489, details={'was_impossible': False}),
#  Prediction(uid=10, iid=455, r_ui=None, est=2.146131006958367, details={'was_impossible': False}),
#  Prediction(uid=10, iid=456, r_ui=None, est=3.15688435389144, details={'was_impossible': False}),
#  Prediction(uid=10, iid=457, r_ui=None, est=3.6525284500716615, details={'was_impossible': False}),
#  Prediction(uid=10, iid=458, r_ui=None, est=2.890243264376033, details={'was_impossible': False}),
#  Prediction(uid=10, iid=459, r_ui=None, est=2.742901911676569, details={'was_impossible': False}),
#  Prediction(uid=10, iid=460, r_ui=None, est=2.9376178923070713, details={'was_impossible': False}),
#  Prediction(uid=10, iid=461, r_ui=None, est=2.7602428047641934, details={'was_impossible': False}),
#  Prediction(uid=10, iid=464, r_ui=None, est=2.7340229483592133, details={'was_impossible': False}),
#  Prediction(uid=10, iid=466, r_ui=None, est=2.533245712792577, details={'was_impossible': False}),
#  Prediction(uid=10, iid=467, r_ui=None, est=3.1700570200250024, details={'was_impossible': False}),
#  Prediction(uid=10, iid=468, r_ui=None, est=2.89282747307977, details={'was_impossible': False}),
#  Prediction(uid=10, iid=469, r_ui=None, est=3.0171601244922734, details={'was_impossible': False}),
#  Prediction(uid=10, iid=470, r_ui=None, est=2.913005395571786, details={'was_impossible': False}),
#  Prediction(uid=10, iid=471, r_ui=None, est=3.1738433964715016, details={'was_impossible': False}),
#  Prediction(uid=10, iid=472, r_ui=None, est=2.913905841342775, details={'was_impossible': False}),
#  Prediction(uid=10, iid=473, r_ui=None, est=2.5003102301901143, details={'was_impossible': False}),
#  Prediction(uid=10, iid=474, r_ui=None, est=3.292291109918516, details={'was_impossible': False}),
#  Prediction(uid=10, iid=475, r_ui=None, est=3.726876074729158, details={'was_impossible': False}),
#  Prediction(uid=10, iid=476, r_ui=None, est=2.8484860929717364, details={'was_impossible': False}),
#  Prediction(uid=10, iid=477, r_ui=None, est=3.090129904662375, details={'was_impossible': False}),
#  Prediction(uid=10, iid=478, r_ui=None, est=3.0481554163862783, details={'was_impossible': False}),
#  Prediction(uid=10, iid=479, r_ui=None, est=2.8167301390185786, details={'was_impossible': False}),
#  Prediction(uid=10, iid=480, r_ui=None, est=3.3920607460941987, details={'was_impossible': False}),
#  Prediction(uid=10, iid=481, r_ui=None, est=2.9616663336238327, details={'was_impossible': False}),
#  Prediction(uid=10, iid=482, r_ui=None, est=3.2534130918733553, details={'was_impossible': False}),
#  Prediction(uid=10, iid=484, r_ui=None, est=2.919548547107666, details={'was_impossible': False}),
#  Prediction(uid=10, iid=485, r_ui=None, est=2.5943733301106096, details={'was_impossible': False}),
#  Prediction(uid=10, iid=486, r_ui=None, est=3.0154186982814055, details={'was_impossible': False}),
#  Prediction(uid=10, iid=487, r_ui=None, est=3.0280688967277736, details={'was_impossible': False}),
#  Prediction(uid=10, iid=488, r_ui=None, est=3.0350033508061403, details={'was_impossible': False}),
#  Prediction(uid=10, iid=489, r_ui=None, est=2.792688547630674, details={'was_impossible': False}),
#  Prediction(uid=10, iid=490, r_ui=None, est=2.9435246359531466, details={'was_impossible': False}),
#  Prediction(uid=10, iid=491, r_ui=None, est=2.8262804373313655, details={'was_impossible': False}),
#  Prediction(uid=10, iid=492, r_ui=None, est=3.2543789941422023, details={'was_impossible': False}),
#  Prediction(uid=10, iid=493, r_ui=None, est=3.1195672031143413, details={'was_impossible': False}),
#  Prediction(uid=10, iid=494, r_ui=None, est=3.100677834808868, details={'was_impossible': False}),
#  Prediction(uid=10, iid=495, r_ui=None, est=3.2223766713691853, details={'was_impossible': False}),
#  Prediction(uid=10, iid=496, r_ui=None, est=3.190038282676934, details={'was_impossible': False}),
#  Prediction(uid=10, iid=497, r_ui=None, est=3.3929023831932392, details={'was_impossible': False}),
#  Prediction(uid=10, iid=499, r_ui=None, est=3.0053645311580874, details={'was_impossible': False}),
#  Prediction(uid=10, iid=500, r_ui=None, est=3.051416301229366, details={'was_impossible': False}),
#  Prediction(uid=10, iid=501, r_ui=None, est=3.1353616084191263, details={'was_impossible': False}),
#  Prediction(uid=10, iid=502, r_ui=None, est=2.3997535570109925, details={'was_impossible': False}),
#  Prediction(uid=10, iid=504, r_ui=None, est=3.052806678142738, details={'was_impossible': False}),
#  Prediction(uid=10, iid=505, r_ui=None, est=2.5364874205300105, details={'was_impossible': False}),
#  Prediction(uid=10, iid=506, r_ui=None, est=3.246913766092882, details={'was_impossible': False}),
#  Prediction(uid=10, iid=507, r_ui=None, est=3.084583267520253, details={'was_impossible': False}),
#  Prediction(uid=10, iid=508, r_ui=None, est=3.3258896687663335, details={'was_impossible': False}),
#  Prediction(uid=10, iid=509, r_ui=None, est=3.2652353078391396, details={'was_impossible': False}),
#  Prediction(uid=10, iid=510, r_ui=None, est=3.019428125915194, details={'was_impossible': False}),
#  Prediction(uid=10, iid=511, r_ui=None, est=2.9729173870711008, details={'was_impossible': False}),
#  Prediction(uid=10, iid=512, r_ui=None, est=2.9870886928025953, details={'was_impossible': False}),
#  Prediction(uid=10, iid=513, r_ui=None, est=3.090862989044241, details={'was_impossible': False}),
#  Prediction(uid=10, iid=514, r_ui=None, est=3.0806402010321134, details={'was_impossible': False}),
#  Prediction(uid=10, iid=515, r_ui=None, est=3.1471602866271917, details={'was_impossible': False}),
#  Prediction(uid=10, iid=516, r_ui=None, est=2.875713336199611, details={'was_impossible': False}),
#  Prediction(uid=10, iid=517, r_ui=None, est=3.177680875326618, details={'was_impossible': False}),
#  Prediction(uid=10, iid=518, r_ui=None, est=2.915042114316473, details={'was_impossible': False}),
#  Prediction(uid=10, iid=519, r_ui=None, est=2.3261509220204073, details={'was_impossible': False}),
#  Prediction(uid=10, iid=520, r_ui=None, est=2.788634863099607, details={'was_impossible': False}),
#  Prediction(uid=10, iid=521, r_ui=None, est=3.050684043540818, details={'was_impossible': False}),
#  Prediction(uid=10, iid=522, r_ui=None, est=2.9746929387066077, details={'was_impossible': False}),
#  Prediction(uid=10, iid=523, r_ui=None, est=2.979523157077571, details={'was_impossible': False}),
#  Prediction(uid=10, iid=524, r_ui=None, est=3.057981888334985, details={'was_impossible': False}),
#  Prediction(uid=10, iid=526, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=527, r_ui=None, est=3.806479121810953, details={'was_impossible': False}),
#  Prediction(uid=10, iid=528, r_ui=None, est=2.988351030943998, details={'was_impossible': False}),
#  Prediction(uid=10, iid=529, r_ui=None, est=3.4885074240839997, details={'was_impossible': False}),
#  Prediction(uid=10, iid=531, r_ui=None, est=2.9564151641312204, details={'was_impossible': False}),
#  Prediction(uid=10, iid=532, r_ui=None, est=2.8372812996393137, details={'was_impossible': False}),
#  Prediction(uid=10, iid=533, r_ui=None, est=2.7934416206455004, details={'was_impossible': False}),
#  Prediction(uid=10, iid=534, r_ui=None, est=3.2827606735177843, details={'was_impossible': False}),
#  Prediction(uid=10, iid=535, r_ui=None, est=3.050475546172894, details={'was_impossible': False}),
#  Prediction(uid=10, iid=536, r_ui=None, est=3.077770406570535, details={'was_impossible': False}),
#  Prediction(uid=10, iid=537, r_ui=None, est=2.934092095582228, details={'was_impossible': False}),
#  Prediction(uid=10, iid=538, r_ui=None, est=3.12469427521497, details={'was_impossible': False}),
#  Prediction(uid=10, iid=539, r_ui=None, est=3.1739990290990514, details={'was_impossible': False}),
#  Prediction(uid=10, iid=540, r_ui=None, est=2.831835803790707, details={'was_impossible': False}),
#  Prediction(uid=10, iid=541, r_ui=None, est=3.8133355066047505, details={'was_impossible': False}),
#  Prediction(uid=10, iid=542, r_ui=None, est=2.544723770665422, details={'was_impossible': False}),
#  Prediction(uid=10, iid=543, r_ui=None, est=2.983587886179004, details={'was_impossible': False}),
#  Prediction(uid=10, iid=544, r_ui=None, est=2.818368499144755, details={'was_impossible': False}),
#  Prediction(uid=10, iid=546, r_ui=None, est=2.0071450202305696, details={'was_impossible': False}),
#  Prediction(uid=10, iid=547, r_ui=None, est=3.0740302525988144, details={'was_impossible': False}),
#  Prediction(uid=10, iid=548, r_ui=None, est=2.937721386858509, details={'was_impossible': False}),
#  Prediction(uid=10, iid=549, r_ui=None, est=3.176878934931345, details={'was_impossible': False}),
#  Prediction(uid=10, iid=550, r_ui=None, est=3.0476779388114883, details={'was_impossible': False}),
#  Prediction(uid=10, iid=551, r_ui=None, est=3.237509380246871, details={'was_impossible': False}),
#  Prediction(uid=10, iid=552, r_ui=None, est=2.8508077902754447, details={'was_impossible': False}),
# ...
#  Prediction(uid=10, iid=1117, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1119, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1120, r_ui=None, est=3.304119865374967, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1121, r_ui=None, est=3.1265906103522108, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1123, r_ui=None, est=3.1676211276490798, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1124, r_ui=None, est=3.172112782964138, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1125, r_ui=None, est=3.210356169802249, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1126, r_ui=None, est=2.9596875278730277, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1127, r_ui=None, est=3.2296213194092753, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1128, r_ui=None, est=2.9688956335777745, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1129, r_ui=None, est=3.129704154659678, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1130, r_ui=None, est=2.8718747118385823, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1131, r_ui=None, est=3.4460383652904047, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1132, r_ui=None, est=3.361858387518615, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1135, r_ui=None, est=2.9236375894896587, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1136, r_ui=None, est=3.891416099355222, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1137, r_ui=None, est=3.082505370507513, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1140, r_ui=None, est=3.206983970021294, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1144, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1147, r_ui=None, est=3.302336947716776, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1148, r_ui=None, est=3.6671977163464318, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1150, r_ui=None, est=3.2985727604741255, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1151, r_ui=None, est=3.164346405035343, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1156, r_ui=None, est=3.061688779964977, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1161, r_ui=None, est=3.1180753876753755, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1162, r_ui=None, est=3.0208208473899787, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1163, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1167, r_ui=None, est=3.028695102645262, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1170, r_ui=None, est=2.932178365320525, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1171, r_ui=None, est=2.9791370708324143, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1172, r_ui=None, est=3.7794149021463324, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1173, r_ui=None, est=2.669559373051423, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1175, r_ui=None, est=3.379195747725908, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1176, r_ui=None, est=3.1813385469769226, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1177, r_ui=None, est=3.2074479922171846, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1178, r_ui=None, est=3.6813279303279742, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1179, r_ui=None, est=3.1829837604697113, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1180, r_ui=None, est=3.0181555152435813, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1183, r_ui=None, est=3.2868603561686407, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1184, r_ui=None, est=3.057436971481133, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1185, r_ui=None, est=3.2669226343422615, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1186, r_ui=None, est=3.1166093756460174, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1187, r_ui=None, est=3.058425116360184, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1188, r_ui=None, est=3.4391066429959145, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1189, r_ui=None, est=3.425061816557724, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1190, r_ui=None, est=2.889588433356736, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1191, r_ui=None, est=3.1236440113004105, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1192, r_ui=None, est=3.301538472070635, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1193, r_ui=None, est=3.820199747633536, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1194, r_ui=None, est=3.3454601810019344, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1196, r_ui=None, est=3.7307996565624264, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1197, r_ui=None, est=3.840052585615818, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1198, r_ui=None, est=3.8032470473926017, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1199, r_ui=None, est=3.8408678960386595, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1200, r_ui=None, est=3.645733008651599, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1201, r_ui=None, est=3.865279159899566, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1202, r_ui=None, est=3.2708366940287346, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1203, r_ui=None, est=3.7911899923926446, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1204, r_ui=None, est=3.9765353246133452, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1206, r_ui=None, est=3.6648464377972716, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1207, r_ui=None, est=3.682864651247552, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1208, r_ui=None, est=3.8581530681975718, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1209, r_ui=None, est=3.59036418961238, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1210, r_ui=None, est=3.7226025928007687, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1211, r_ui=None, est=3.140852964496981, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1212, r_ui=None, est=3.6649102368131987, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1213, r_ui=None, est=3.7871830757434113, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1214, r_ui=None, est=3.5249933596512566, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1215, r_ui=None, est=3.4999790452072337, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1216, r_ui=None, est=3.273696366230449, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1217, r_ui=None, est=3.718004233036822, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1218, r_ui=None, est=3.32097439500959, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1219, r_ui=None, est=3.7059750597952927, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1220, r_ui=None, est=3.433264170833885, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1221, r_ui=None, est=3.827898981498035, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1222, r_ui=None, est=3.7197668403760025, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1223, r_ui=None, est=3.9573047670174026, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1224, r_ui=None, est=3.2949303655970037, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1225, r_ui=None, est=3.755731262308914, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1226, r_ui=None, est=3.0675182697015657, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1227, r_ui=None, est=3.3574065042544574, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1228, r_ui=None, est=3.6178822677422056, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1230, r_ui=None, est=3.616488536722295, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1231, r_ui=None, est=3.5617001938213333, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1232, r_ui=None, est=3.2509748936649476, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1233, r_ui=None, est=3.707473352128747, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1234, r_ui=None, est=3.623527232824963, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1235, r_ui=None, est=3.717810424784099, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1236, r_ui=None, est=3.2581286133624667, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1237, r_ui=None, est=3.4390615689815007, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1238, r_ui=None, est=3.5364695256397582, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1240, r_ui=None, est=3.4987373258076846, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1241, r_ui=None, est=3.3085618758145983, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1242, r_ui=None, est=3.783128414380297, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1243, r_ui=None, est=3.558565969216824, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1244, r_ui=None, est=3.5471092759465783, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1245, r_ui=None, est=3.6148094014125425, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1246, r_ui=None, est=3.4869944404221305, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1248, r_ui=None, est=3.7976070391016132, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1249, r_ui=None, est=3.6931192209073913, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1250, r_ui=None, est=3.634757759160602, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1251, r_ui=None, est=3.5317075199637444, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1252, r_ui=None, est=3.6969025986526507, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1253, r_ui=None, est=3.4108966346183975, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1254, r_ui=None, est=3.313405048049134, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1255, r_ui=None, est=2.971188886710977, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1256, r_ui=None, est=3.4526978164160216, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1257, r_ui=None, est=3.353953270170253, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1258, r_ui=None, est=3.7079748951823244, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1259, r_ui=None, est=3.5737802000998533, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1260, r_ui=None, est=3.2307401556587902, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1261, r_ui=None, est=3.713033712732478, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1262, r_ui=None, est=3.813837102189427, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1263, r_ui=None, est=3.3954377230384427, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1264, r_ui=None, est=3.1362432758157652, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1265, r_ui=None, est=3.5308016381816323, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1266, r_ui=None, est=3.678436402807417, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1267, r_ui=None, est=3.7087627102474925, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1268, r_ui=None, est=3.232347233991204, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1269, r_ui=None, est=3.4654123326018214, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1270, r_ui=None, est=3.7021306600269543, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1271, r_ui=None, est=3.1924744851708264, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1272, r_ui=None, est=3.5002679854939007, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1273, r_ui=None, est=3.4966212672373507, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1274, r_ui=None, est=3.6200276476958675, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1275, r_ui=None, est=3.5582038620373453, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1276, r_ui=None, est=3.78288495235295, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1277, r_ui=None, est=3.4450352862525424, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1278, r_ui=None, est=3.6143526041159566, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1279, r_ui=None, est=3.2618445611404785, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1280, r_ui=None, est=3.4692034825669493, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1281, r_ui=None, est=3.553670817624039, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1282, r_ui=None, est=3.3849059094350764, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1283, r_ui=None, est=3.8299148506885414, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1284, r_ui=None, est=3.5247970630849528, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1285, r_ui=None, est=3.338569137045341, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1286, r_ui=None, est=3.079988870652058, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1287, r_ui=None, est=3.452557454733367, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1288, r_ui=None, est=3.661913698574337, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1289, r_ui=None, est=3.213941058365573, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1290, r_ui=None, est=3.0509663890524052, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1291, r_ui=None, est=3.694676601947126, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1292, r_ui=None, est=3.522039729159953, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1293, r_ui=None, est=3.511964781262424, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1295, r_ui=None, est=2.924797551086817, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1296, r_ui=None, est=3.4083172494682765, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1297, r_ui=None, est=3.33513023663952, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1298, r_ui=None, est=3.4931048669567724, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1299, r_ui=None, est=3.5570315047524024, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1300, r_ui=None, est=3.391794481900413, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1301, r_ui=None, est=3.2333950428057125, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1302, r_ui=None, est=3.1614195326533423, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1303, r_ui=None, est=3.6467526580112404, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1304, r_ui=None, est=3.5335208401499743, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1305, r_ui=None, est=3.1082402550562143, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1306, r_ui=None, est=2.9924870513928266, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1310, r_ui=None, est=3.214879065522665, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1312, r_ui=None, est=3.0193216168305916, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1318, r_ui=None, est=3.068219885372118, details={'was_impossible': False}),
#  ...]

# %% [markdown]
# ## Sort the predicted ratings in top 10

# %%
sorted_predictions_user = sorted(predictions_user, key=lambda x: x.est, reverse=True)

top_10_predictions_user = sorted_predictions_user[:10]
top_10_predictions_user
# Out:
# [Prediction(uid=10, iid=1204, r_ui=None, est=3.9765353246133452, details={'was_impossible': False}),
#  Prediction(uid=10, iid=750, r_ui=None, est=3.975747033883747, details={'was_impossible': False}),
#  Prediction(uid=10, iid=318, r_ui=None, est=3.974798966428555, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1223, r_ui=None, est=3.9573047670174026, details={'was_impossible': False}),
#  Prediction(uid=10, iid=904, r_ui=None, est=3.9018937208855626, details={'was_impossible': False}),
#  Prediction(uid=10, iid=1136, r_ui=None, est=3.891416099355222, details={'was_impossible': False}),
#  Prediction(uid=10, iid=50, r_ui=None, est=3.8900893100040244, details={'was_impossible': False}),
#  Prediction(uid=10, iid=2019, r_ui=None, est=3.8719647491416023, details={'was_impossible': False}),
#  Prediction(uid=10, iid=3275, r_ui=None, est=3.8719537804564936, details={'was_impossible': False}),
#  Prediction(uid=10, iid=5618, r_ui=None, est=3.868923684061274, details={'was_impossible': False})]

# %% [markdown]
# ## Create a dataframe that maps movieId to titles genres tags

# %%
#### Get top 10 movie ids ####
movie_ids = [prediction.iid for prediction in top_10_predictions_user]


# Movie_ids to dataframe 
movie_ids_df = pd.DataFrame({'movieId': movie_ids})

# Find corresponding titles and genres from the movies DataFrame
movies_pred = pd.merge(movie_ids_df, movies, on='movieId', how='left')

estimated_ratings = [prediction.est for prediction in top_10_predictions_user]
movies_pred['est_rating'] = estimated_ratings

##### change columns ######
movies_pred = movies_pred[['movieId', 'title', 'genres', 'est_rating']]
movies_pred
# Out:
#    movieId                                              title  \
# 0     1204                          Lawrence of Arabia (1962)
# 1      750  Dr. Strangelove or: How I Learned to Stop Worr...
# 2      318                   Shawshank Redemption, The (1994)
# 3     1223    Grand Day Out with Wallace and Gromit, A (1989)
# 4      904                                 Rear Window (1954)
# 5     1136             Monty Python and the Holy Grail (1975)
# 6       50                         Usual Suspects, The (1995)
# 7     2019        Seven Samurai (Shichinin no samurai) (1954)
# 8     3275                        Boondock Saints, The (2000)
# 9     5618  Spirited Away (Sen to Chihiro no kamikakushi) ...
#
#                                        genres  est_rating
# 0                         Adventure|Drama|War    3.976535
# 1                                  Comedy|War    3.975747
# 2                                 Crime|Drama    3.974799
# 3  Adventure|Animation|Children|Comedy|Sci-Fi    3.957305
# 4                            Mystery|Thriller    3.901894
# 5                    Adventure|Comedy|Fantasy    3.891416
# 6                      Crime|Mystery|Thriller    3.890089
# 7                      Action|Adventure|Drama    3.871965
# 8                 Action|Crime|Drama|Thriller    3.871954
# 9                 Adventure|Animation|Fantasy    3.868924

# %% [markdown]
# # NEURAL

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
import keras
from keras import layers
import time
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
ratings_nn = pd.read_csv("ratings.csv")

# %% [markdown]
# # Encode users and movies as integer indices.

# %%
user_ids = ratings_nn["userId"].unique().tolist()
user2user_encoded = {x: i for i, x in enumerate(user_ids)}
userencoded2user = {i: x for i, x in enumerate(user_ids)}
movie_ids = ratings_nn["movieId"].unique().tolist()
movie2movie_encoded = {x: i for i, x in enumerate(movie_ids)}
movie_encoded2movie = {i: x for i, x in enumerate(movie_ids)}
ratings_nn["user"] = ratings_nn["userId"].map(user2user_encoded)
ratings_nn["movie"] = ratings_nn["movieId"].map(movie2movie_encoded)

num_users = len(user2user_encoded)
num_movies = len(movie_encoded2movie)
ratings_nn["rating"] = ratings_nn["rating"].values.astype(np.float32)

min_rating = min(ratings_nn["rating"])
max_rating = max(ratings_nn["rating"])

# %% [markdown]
# # Normalization of ratings

# %%
ratings_nn = ratings_nn.sample(frac=1, random_state=42)
x = ratings_nn[["user", "movie"]].values
# Normalize the targets between 0 and 1. Makes it easy to train.
y = ratings_nn["rating"].apply(lambda x: (x - min_rating) / (max_rating - min_rating)).values
# Assuming training on 90% of the data and validating on 10%.
train_indices = int(0.9 * ratings_nn.shape[0])
x_train, x_val, y_train, y_val = (
    x[:train_indices],
    x[train_indices:],
    y[:train_indices],
    y[train_indices:],
)

# %% [markdown]
# # We embed both users and movies in to 50-dimensional vectors.
#
# **The model computes a match score between user and movie embeddings via a dot product, and adds a per-movie and per-user bias. The match score is scaled to the [0, 1] interval via a sigmoid**

# %%
import tensorflow as tf
from tensorflow.keras import layers

EMBEDDING_SIZE = 50

class RecommenderNet(tf.keras.Model):
    def __init__(self, num_users, num_movies, embedding_size, **kwargs):
        super().__init__(**kwargs)
        self.num_users = num_users
        self.num_movies = num_movies
        self.embedding_size = embedding_size
        self.user_embedding = layers.Embedding(
            num_users,
            embedding_size,
            embeddings_initializer="he_normal",
            embeddings_regularizer=tf.keras.regularizers.l2(1e-6),
        )
        self.user_bias = layers.Embedding(num_users, 1)
        self.movie_embedding = layers.Embedding(
            num_movies,
            embedding_size,
            embeddings_initializer="he_normal",
            embeddings_regularizer=tf.keras.regularizers.l2(1e-6),
        )
        self.movie_bias = layers.Embedding(num_movies, 1)

    def call(self, inputs):
        user_vector = self.user_embedding(inputs[:, 0])
        user_bias = self.user_bias(inputs[:, 0])
        movie_vector = self.movie_embedding(inputs[:, 1])
        movie_bias = self.movie_bias(inputs[:, 1])
        dot_user_movie = tf.reduce_sum(user_vector * movie_vector, axis=1, keepdims=True)
        # Add all the components (including bias)
        x = dot_user_movie + user_bias + movie_bias
        # The sigmoid activation forces the rating to between 0 and 1
        return tf.nn.sigmoid(x)
    
    
start_time = time.time()
model = RecommenderNet(num_users, num_movies, EMBEDDING_SIZE)
model.compile(
    loss=tf.keras.losses.BinaryCrossentropy(),
    optimizer=tf.keras.optimizers.Adam(learning_rate=0.001),
)

####### Train model ######
history = model.fit(
    x=x_train,
    y=y_train,
    batch_size=64,
    epochs=5,
    verbose=1,
    validation_data=(x_val, y_val),
)
end_time = time.time()
total_time = end_time - start_time
print(f"Total time taken: {total_time} seconds")
# Out:
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# Epoch 1/5
# WARNING:tensorflow:From C:\Users\user\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 1418/1418 [==============================] - 11s 7ms/step - loss: 0.6466 - val_loss: 0.6123
# Epoch 2/5
# 1418/1418 [==============================] - 10s 7ms/step - loss: 0.5951 - val_loss: 0.6021
# Epoch 3/5
# 1418/1418 [==============================] - 10s 7ms/step - loss: 0.5787 - val_loss: 0.6002
# Epoch 4/5
# 1418/1418 [==============================] - 10s 7ms/step - loss: 0.5654 - val_loss: 0.6011
# Epoch 5/5
# 1418/1418 [==============================] - 10s 7ms/step - loss: 0.5548 - val_loss: 0.6032
# Total time taken: 51.39318513870239 seconds

# %% [markdown]
# # Plot training and validation loss (binary cross entropy)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(style="whitegrid")  

plt.figure(figsize=(10, 6))  

# Plot training and validation loss
sns.lineplot(x=range(1, len(history.history["loss"]) + 1), y=history.history["loss"], label="Train")
sns.lineplot(x=range(1, len(history.history["val_loss"]) + 1), y=history.history["val_loss"], label="Test")

plt.title("Binary Cross Entropy Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend(loc="upper right")
plt.show()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\1712822759.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   plt.show()

# %% [markdown]
# **We can see that while train test is getting lower every epoch, the validation set is increasing his loss after epoch 2**

# %%
mv_df = pd.read_csv("movies.csv")

# %% [markdown]
# # Top 10 movie recommendation

# %%
movies_watched_by_user = ratings_nn[ratings_nn.userId == user_id]
movies_not_watched = mv_df[
    ~mv_df["movieId"].isin(movies_watched_by_user.movieId.values)
]["movieId"]
movies_not_watched = list(
    set(movies_not_watched).intersection(set(movie2movie_encoded.keys()))
)
movies_not_watched = [[movie2movie_encoded.get(x)] for x in movies_not_watched]
user_encoder = user2user_encoded.get(user_id)
user_movie_array = np.hstack(
    ([[user_encoder]] * len(movies_not_watched), movies_not_watched)
)
pred_ratings_nn = model.predict(user_movie_array).flatten()
top_ratings_indices = pred_ratings_nn.argsort()[-10:][::-1]
recommended_movie_ids = [
    movie_encoded2movie.get(movies_not_watched[x][0]) for x in top_ratings_indices
]
# Out:
# 300/300 [==============================] - 0s 913us/step

# %%
# Movie_ids to dataframe 
movie_ids_nn = pd.DataFrame({'movieId': recommended_movie_ids})

# Find corresponding titles and genres from the movies DataFrame
movies_pred_nn = pd.merge(movie_ids_nn, movies, on='movieId', how='left')

##### change columns ######
movies_pred_nn = movies_pred_nn
movies_pred_nn
# Out:
#    movieId                             title  \
# 0      168               First Knight (1995)
# 1      150                  Apollo 13 (1995)
# 2     3753               Patriot, The (2000)
# 3     3825                Coyote Ugly (2000)
# 4      736                    Twister (1996)
# 5      802                 Phenomenon (1996)
# 6      318  Shawshank Redemption, The (1994)
# 7       11    American President, The (1995)
# 8      595       Beauty and the Beast (1991)
# 9      225                 Disclosure (1994)
#
#                                             genres
# 0                             Action|Drama|Romance
# 1                             Adventure|Drama|IMAX
# 2                                 Action|Drama|War
# 3                             Comedy|Drama|Romance
# 4                Action|Adventure|Romance|Thriller
# 5                                    Drama|Romance
# 6                                      Crime|Drama
# 7                             Comedy|Drama|Romance
# 8  Animation|Children|Fantasy|Musical|Romance|IMAX
# 9                                   Drama|Thriller

# %% [markdown]
# # Content based filtering using titles and genres as features in item profile

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from ast import literal_eval
#pip install sentence-transformers

# %% [markdown]
# # Copy of movies in order not to affect the movies dataframe

# %%
movies2 = pd.read_csv("movies.csv")

# %%
movies_content = movies2.copy()

# %%
movies_content
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9737   193581  Black Butler: Book of the Atlantic (2017)
# 9738   193583               No Game No Life: Zero (2017)
# 9739   193585                               Flint (2017)
# 9740   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9741   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9737              Action|Animation|Comedy|Fantasy
# 9738                     Animation|Comedy|Fantasy
# 9739                                        Drama
# 9740                             Action|Animation
# 9741                                       Comedy
#
# [9742 rows x 3 columns]

# %% [markdown]
# # Check in format title to see how many movies do not have year. Format title has either 'title (year) ' or 'title (year1-year2) '

# %%
titles_without_year = movies_content[~movies_content['title'].str.contains(r'\(\d{4}(?:–\d{4})?\)')]
titles_without_year
# Out:
#       movieId                                              title  \
# 6059    40697                                          Babylon 5
# 9031   140956                                   Ready Player One
# 9091   143410                                         Hyena Road
# 9138   147250  The Adventures of Sherlock Holmes and Doctor W...
# 9179   149334                                  Nocturnal Animals
# 9259   156605                                           Paterson
# 9367   162414                                          Moonlight
# 9448   167570                                             The OA
# 9514   171495                                             Cosmos
# 9515   171631                            Maria Bamford: Old Baby
# 9525   171891                                  Generation Iron 2
# 9611   176601                                       Black Mirror
#
#                       genres
# 6059                  Sci-Fi
# 9031  Action|Sci-Fi|Thriller
# 9091      (no genres listed)
# 9138      (no genres listed)
# 9179          Drama|Thriller
# 9259      (no genres listed)
# 9367                   Drama
# 9448      (no genres listed)
# 9514      (no genres listed)
# 9515      (no genres listed)
# 9525      (no genres listed)
# 9611      (no genres listed)

# %% [markdown]
# # Extract year from title and add a new column where we store year

# %%
movies_content['year'] = movies_content['title'].str.extract(r'\((\d{4}(?:–\d{4})?)\)')

# %%
movies_content.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %% [markdown]
# # Remove year from the title column

# %%
movies_content['title'] = movies_content['title'].str.replace(r'\s*\(\d{4}(?:–\d{4})?\)', '')
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_10640\1456090731.py:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   movies_content['title'] = movies_content['title'].str.replace(r'\s*\(\d{4}(?:–\d{4})?\)', '')

# %%
movies_content.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995

# %%
### Check if a movie doesnt have title ###
movies_content["title"].isnull().sum()
# Out:
# 0

# %% [markdown]
# # Remove movies that doesnt have genres

# %%
movies_content[movies_content["genres"] == '(no genres listed)']
# Out:
#       movieId                                              title  \
# 8517   114335                                         La cravate
# 8684   122888                                            Ben-hur
# 8687   122896   Pirates of the Caribbean: Dead Men Tell No Tales
# 8782   129250                                         Superfast!
# 8836   132084                                       Let It Be Me
# 8902   134861                      Trevor Noah: African American
# 9033   141131                                          Guardians
# 9053   141866                                         Green Room
# 9070   142456                            The Brand New Testament
# 9091   143410                                         Hyena Road
# 9138   147250  The Adventures of Sherlock Holmes and Doctor W...
# 9178   149330                                 A Cosmic Christmas
# 9217   152037                                        Grease Live
# 9248   155589                                    Noin 7 veljestä
# 9259   156605                                           Paterson
# 9307   159161                               Ali Wong: Baby Cobra
# 9316   159779                          A Midsummer Night's Dream
# 9348   161008                                The Forbidden Dance
# 9413   165489                                     Ethel & Ernest
# 9426   166024                                           Whiplash
# 9448   167570                                             The OA
# 9478   169034                                           Lemonade
# 9514   171495                                             Cosmos
# 9515   171631                            Maria Bamford: Old Baby
# 9518   171749                              Death Note: Desu nôto
# 9525   171891                                  Generation Iron 2
# 9534   172497                         T2 3-D: Battle Across Time
# 9541   172591                   The Godfather Trilogy: 1972-1990
# 9562   173535  The Adventures of Sherlock Holmes and Doctor W...
# 9573   174403                               The Putin Interviews
# 9611   176601                                       Black Mirror
# 9661   181413  Too Funny to Fail: The Life and Death of The D...
# 9663   181719  Serving in Silence: The Margarethe Cammermeyer...
# 9669   182727                            A Christmas Story Live!
#
#                   genres       year
# 8517  (no genres listed)       1957
# 8684  (no genres listed)       2016
# 8687  (no genres listed)       2017
# 8782  (no genres listed)       2015
# 8836  (no genres listed)       1995
# 8902  (no genres listed)       2013
# 9033  (no genres listed)       2016
# 9053  (no genres listed)       2015
# 9070  (no genres listed)       2015
# 9091  (no genres listed)        NaN
# 9138  (no genres listed)        NaN
# 9178  (no genres listed)       1977
# 9217  (no genres listed)       2016
# 9248  (no genres listed)       1968
# 9259  (no genres listed)        NaN
# 9307  (no genres listed)       2016
# 9316  (no genres listed)       2016
# 9348  (no genres listed)       1990
# 9413  (no genres listed)       2016
# 9426  (no genres listed)       2013
# 9448  (no genres listed)        NaN
# 9478  (no genres listed)       2016
# 9514  (no genres listed)        NaN
# 9515  (no genres listed)        NaN
# 9518  (no genres listed)  2006–2007
# 9525  (no genres listed)        NaN
# 9534  (no genres listed)       1996
# 9541  (no genres listed)       1992
# 9562  (no genres listed)       1980
# 9573  (no genres listed)       2017
# 9611  (no genres listed)        NaN
# 9661  (no genres listed)       2017
# 9663  (no genres listed)       1995
# 9669  (no genres listed)       2017

# %%
movies_content = movies_content[movies_content["genres"] != '(no genres listed)']

# %% [markdown]
# # Reset index because some rows deleted

# %%
movies_content= movies_content.reset_index(drop=True)

# %%
movies_content
# Out:
#       movieId                               title  \
# 0           1                           Toy Story
# 1           2                             Jumanji
# 2           3                    Grumpier Old Men
# 3           4                   Waiting to Exhale
# 4           5         Father of the Bride Part II
# ...       ...                                 ...
# 9703   193581  Black Butler: Book of the Atlantic
# 9704   193583               No Game No Life: Zero
# 9705   193585                               Flint
# 9706   193587        Bungo Stray Dogs: Dead Apple
# 9707   193609        Andrew Dice Clay: Dice Rules
#
#                                            genres  year
# 0     Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                      Adventure|Children|Fantasy  1995
# 2                                  Comedy|Romance  1995
# 3                            Comedy|Drama|Romance  1995
# 4                                          Comedy  1995
# ...                                           ...   ...
# 9703              Action|Animation|Comedy|Fantasy  2017
# 9704                     Animation|Comedy|Fantasy  2017
# 9705                                        Drama  2017
# 9706                             Action|Animation  2018
# 9707                                       Comedy  1991
#
# [9708 rows x 4 columns]

# %% [markdown]
# # Initialize model and remove | from genres in order to process them

# %%
from sentence_transformers import SentenceTransformer

model = SentenceTransformer('all-mpnet-base-v2')

# %%
movies_content['genres_list'] = movies_content['genres'].str.split('|')

# %%
movies_content.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995
#
#                                          genres_list
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]

# %%
movies_content["title_list"] = movies_content['title'].apply(lambda x: [x]).tolist()

# %%
movies_content.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995
#
#                                          genres_list  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
#
#                       title_list
# 0                    [Toy Story]
# 1                      [Jumanji]
# 2             [Grumpier Old Men]
# 3            [Waiting to Exhale]
# 4  [Father of the Bride Part II]

# %%
movies_content['metadata'] = movies_content['title_list'] + movies_content['genres_list']

# %%
movies_content.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995
#
#                                          genres_list  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
#
#                       title_list  \
# 0                    [Toy Story]
# 1                      [Jumanji]
# 2             [Grumpier Old Men]
# 3            [Waiting to Exhale]
# 4  [Father of the Bride Part II]
#
#                                             metadata
# 0  [Toy Story, Adventure, Animation, Children, Co...
# 1            [Jumanji, Adventure, Children, Fantasy]
# 2                [Grumpier Old Men, Comedy, Romance]
# 3        [Waiting to Exhale, Comedy, Drama, Romance]
# 4              [Father of the Bride Part II, Comedy]

# %% [markdown]
# # Sentence transformer expects a list of strings <br>
# ## These strings are the title of the movie and their genres

# %%
movies_content['metadata'] = movies_content['metadata'].apply(lambda x: ' '.join(x))

# %%
movies_content.head()
# Out:
#    movieId                        title  \
# 0        1                    Toy Story
# 1        2                      Jumanji
# 2        3             Grumpier Old Men
# 3        4            Waiting to Exhale
# 4        5  Father of the Bride Part II
#
#                                         genres  year  \
# 0  Adventure|Animation|Children|Comedy|Fantasy  1995
# 1                   Adventure|Children|Fantasy  1995
# 2                               Comedy|Romance  1995
# 3                         Comedy|Drama|Romance  1995
# 4                                       Comedy  1995
#
#                                          genres_list  \
# 0  [Adventure, Animation, Children, Comedy, Fantasy]
# 1                     [Adventure, Children, Fantasy]
# 2                                  [Comedy, Romance]
# 3                           [Comedy, Drama, Romance]
# 4                                           [Comedy]
#
#                       title_list  \
# 0                    [Toy Story]
# 1                      [Jumanji]
# 2             [Grumpier Old Men]
# 3            [Waiting to Exhale]
# 4  [Father of the Bride Part II]
#
#                                             metadata
# 0  Toy Story Adventure Animation Children Comedy ...
# 1                 Jumanji Adventure Children Fantasy
# 2                    Grumpier Old Men Comedy Romance
# 3             Waiting to Exhale Comedy Drama Romance
# 4                 Father of the Bride Part II Comedy

# %%
meta_data = np.array(movies_content['metadata'])
meta_data
# Out:
# array(['Toy Story Adventure Animation Children Comedy Fantasy',
#        'Jumanji Adventure Children Fantasy',
#        'Grumpier Old Men Comedy Romance', ..., 'Flint Drama',
#        'Bungo Stray Dogs: Dead Apple Action Animation',
#        'Andrew Dice Clay: Dice Rules Comedy'], dtype=object)

# %%
embeddings = model.encode(meta_data, show_progress_bar=True)
# Out:
# Batches:   0%|          | 0/304 [00:00<?, ?it/s]

# %%
embeddings.shape
# Out:
# (9708, 768)

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
sim_matrix = cosine_similarity(embeddings)
sim_matrix
# Out:
# array([[1.0000001 , 0.5237799 , 0.23131318, ..., 0.14419204, 0.3691797 ,
#         0.26906765],
#        [0.5237799 , 0.99999994, 0.17015618, ..., 0.15566926, 0.24296936,
#         0.12710135],
#        [0.23131318, 0.17015618, 0.9999999 , ..., 0.14382234, 0.13827826,
#         0.24506736],
#        ...,
#        [0.14419204, 0.15566926, 0.14382234, ..., 0.99999994, 0.09317985,
#         0.23325431],
#        [0.3691797 , 0.24296936, 0.13827826, ..., 0.09317985, 1.0000002 ,
#         0.14965002],
#        [0.26906765, 0.12710135, 0.24506736, ..., 0.23325431, 0.14965002,
#         1.0000001 ]], dtype=float32)

# %% [markdown]
# # Get top 10 similar movies with the one that we prompt. <br>
# ## The display will be on the movies2 dataframe and not on the processed df.

# %%
movies2 = movies2[movies2["genres"] != '(no genres listed)']

# %%
movies2= movies2.reset_index(drop=True)

# %%
movies2
# Out:
#       movieId                                      title  \
# 0           1                           Toy Story (1995)
# 1           2                             Jumanji (1995)
# 2           3                    Grumpier Old Men (1995)
# 3           4                   Waiting to Exhale (1995)
# 4           5         Father of the Bride Part II (1995)
# ...       ...                                        ...
# 9703   193581  Black Butler: Book of the Atlantic (2017)
# 9704   193583               No Game No Life: Zero (2017)
# 9705   193585                               Flint (2017)
# 9706   193587        Bungo Stray Dogs: Dead Apple (2018)
# 9707   193609        Andrew Dice Clay: Dice Rules (1991)
#
#                                            genres
# 0     Adventure|Animation|Children|Comedy|Fantasy
# 1                      Adventure|Children|Fantasy
# 2                                  Comedy|Romance
# 3                            Comedy|Drama|Romance
# 4                                          Comedy
# ...                                           ...
# 9703              Action|Animation|Comedy|Fantasy
# 9704                     Animation|Comedy|Fantasy
# 9705                                        Drama
# 9706                             Action|Animation
# 9707                                       Comedy
#
# [9708 rows x 3 columns]

# %%
top_movies_for_user
# Out:
#        movieId                          title  \
# 99259   140110              The Intern (2015)
# 77147     8869          First Daughter (2004)
# 94672    96079                 Skyfall (2012)
# 93816    91529  Dark Knight Rises, The (2012)
# 75192     7458                    Troy (2004)
# 92100    81845      King's Speech, The (2010)
# 76341     8533           Notebook, The (2004)
# 91318    79091           Despicable Me (2010)
# 90172    71579           Education, An (2009)
# 80014    33794           Batman Begins (2005)
#
#                                 genres  userId  rating
# 99259                           Comedy      10     5.0
# 77147                   Comedy|Romance      10     5.0
# 94672   Action|Adventure|Thriller|IMAX      10     5.0
# 93816      Action|Adventure|Crime|IMAX      10     5.0
# 75192       Action|Adventure|Drama|War      10     5.0
# 92100                            Drama      10     5.0
# 76341                    Drama|Romance      10     5.0
# 91318  Animation|Children|Comedy|Crime      10     5.0
# 90172                    Drama|Romance      10     5.0
# 80014                Action|Crime|IMAX      10     5.0

# %% [markdown]
# # User 10 liked Dispicable Me and we want to get top 10 movies similar to Dispicable Me that he will probably like too

# %%
def get_recommendations(movie_title, similarity_matrix, df):
    idx = df[df['title'] == movie_title].index[0]
    sim_scores = list(enumerate(similarity_matrix[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:11]  # Get top 10 similar movies

    movie_indices = [i[0] for i in sim_scores]
    return movies2.loc[movie_indices, ['movieId','title',"genres"]]


movie_title = 'Despicable Me'
recommendations = get_recommendations(movie_title, sim_matrix, movies_content)
recommendations
# Out:
#       movieId                                        title  \
# 9508   172547                       Despicable Me 3 (2017)
# 8200   103335                       Despicable Me 2 (2013)
# 868      1148  Wallace & Gromit: The Wrong Trousers (1993)
# 7180    72226                     Fantastic Mr. Fox (2009)
# 6112    42734                           Hoodwinked! (2005)
# 1517     2048            Great Mouse Detective, The (1986)
# 1081     1405       Beavis and Butt-Head Do America (1996)
# 4859     7262                        Catch That Kid (2004)
# 6212    45517                                  Cars (2006)
# 8918   135887                               Minions (2015)
#
#                                          genres
# 9508        Adventure|Animation|Children|Comedy
# 8200             Animation|Children|Comedy|IMAX
# 868             Animation|Children|Comedy|Crime
# 7180  Adventure|Animation|Children|Comedy|Crime
# 6112                  Animation|Children|Comedy
# 1517            Action|Animation|Children|Crime
# 1081           Adventure|Animation|Comedy|Crime
# 4859     Action|Adventure|Children|Comedy|Crime
# 6212                  Animation|Children|Comedy
# 8918        Adventure|Animation|Children|Comedy
